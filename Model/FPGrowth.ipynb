# %% [markdown]
# # FP-Growth

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd 
import numpy as np
from mlxtend.frequent_patterns import fpgrowth
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ## Preprocessing Phase :

# %% [markdown]
# ### Reading the data :

# %%
df = pd.read_csv("Data/TV shows.csv", header = None )

# %% [markdown]
# ### Convert data into a list of lists:

# %%
TVshows = df.values.astype(str).tolist()

# %% [markdown]
# ### Dropping null values

# %%
def remove_items(test_list, item): ## a function that deletes a given element from a list 
    res = [i for i in test_list if i != item] 
    return res

# %%
## Dropping all null values from each list 
for i in range(len(TVshows)):
    TVshows[i] = remove_items(TVshows[i],'nan')
    TVshows[i] = remove_items(TVshows[i],'Sex Education')

# %% [markdown]
# ### Recreating the dataframe :

# %%
shows = pd.DataFrame({"Watched":TVshows})
pd.options.display.max_colwidth=1000

# %% [markdown]
# ### Transactions Selection :

# %%
## In this section we selected the lists that contain at leasy 19 elemnts so we can get proper results : 
shows = shows[shows['Watched'].apply(lambda x: len(x) >= 19)]

# %% [markdown]
# ### Encoding :

# %%
## Encoding the data using dummy encoding : 
shows_encoded = shows['Watched'].str.join(',').str.get_dummies(',')

# %% [markdown]
# ## Training Phase :

# %% [markdown]
# ### Selecting the most frequently apprearing item sets using the FPGrowth algorithm :

# %%
frequent_itemsets = (fpgrowth(shows_encoded,min_support=0.2, use_colnames=True)).sort_values(by='support', ascending=False)
# Out:
# C:\Users\kn_na\AppData\Local\Programs\Python\Python312\Lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(

# %% [markdown]
# ### Applying the association rules modele :

# %%
rules = association_rules(frequent_itemsets, metric='lift')

# %%
# Sort the rules by support in descending order
rules_df = rules.sort_values(by='lift', ascending=False)
rules_df
# Out:
#                                    antecedents  \
# 396                (The Blacklist, Family Guy)
# 397                 (Atypical, Berlin Station)
# 386                               (Family Guy)
# 390  (The Blacklist, Atypical, Berlin Station)
# 379          (Ozark, Atypical, Berlin Station)
# ..                                         ...
# 192                                    (Hanna)
# 80                              (Demon Slayer)
# 419                              (Outer Banks)
# 81                                     (Ozark)
# 418                                    (Ozark)
#
#                            consequents  antecedent support  \
# 396         (Atypical, Berlin Station)            0.333333
# 397        (The Blacklist, Family Guy)            0.285714
# 386  (Ozark, Atypical, Berlin Station)            0.452381
# 390                       (Family Guy)            0.238095
# 379                       (Family Guy)            0.238095
# ..                                 ...                 ...
# 192                            (Ozark)            0.380952
# 80                             (Ozark)            0.476190
# 419                            (Ozark)            0.357143
# 81                      (Demon Slayer)            0.738095
# 418                      (Outer Banks)            0.738095
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 396            0.285714  0.214286    0.642857  2.250000  0.119048    2.000000
# 397            0.333333  0.214286    0.750000  2.250000  0.119048    2.666667
# 386            0.238095  0.214286    0.473684  1.989474  0.106576    1.447619
# 390            0.452381  0.214286    0.900000  1.989474  0.106576    5.476190
# 379            0.452381  0.214286    0.900000  1.989474  0.106576    5.476190
# ..                  ...       ...         ...       ...       ...         ...
# 192            0.738095  0.238095    0.625000  0.846774 -0.043084    0.698413
# 80             0.738095  0.285714    0.600000  0.812903 -0.065760    0.654762
# 419            0.738095  0.214286    0.600000  0.812903 -0.049320    0.654762
# 81             0.476190  0.285714    0.387097  0.812903 -0.065760    0.854637
# 418            0.357143  0.214286    0.290323  0.812903 -0.049320    0.905844
#
#      zhangs_metric
# 396       0.833333
# 397       0.777778
# 386       0.908213
# 390       0.652778
# 379       0.652778
# ..             ...
# 192      -0.226190
# 80       -0.305263
# 419      -0.263636
# 81       -0.467742
# 418      -0.467742
#
# [464 rows x 10 columns]

# %% [markdown]
# ### Functions :

# %%
##  function for cleaning the results : 
def cleanList(l):
    ## Deleting the useless String parts 
    for i in range(len(l)) :
        l[i]=str(l[i]).replace("frozenset({'",'')
        l[i]=l[i].replace("'})",'')
        l[i]=str(l[i]).replace('frozenset({"','')
        l[i]=l[i].replace('"})','')
        l[i]=l[i].replace('", "',',')
        l[i]=l[i].replace("', '",',')
        l[i]=l[i].replace("', ",',')
        l[i]=l[i].replace(", '",',')
        l[i]=l[i].replace('"','')
    return l;


## Function to recommand a certain number of shows 
def Recommended(show,number=4):
    ## A function that will only select the first 4 Series that has the highest support with the desired show 
    desired_antecedents_value = {show}
    desired_rows = rules_df.loc[rules_df['antecedents'] == desired_antecedents_value]

    ## We only choose the lines in the rules table that has only one elemnt 
    filtered_rows = desired_rows[desired_rows['consequents'].apply(lambda x: len(x) == 1)] 
    
    if not filtered_rows.empty:
        first_4_rows = filtered_rows.head(n)
        result_list = first_4_rows['consequents'].tolist()
        
        return cleanList(result_list)

# %% [markdown]
# ### Converting the frequent itemsets into a dataframe and exporting it into a csv

# %%
dataset=frequent_itemsets['itemsets'].tolist()
dataset = cleanList(dataset)
dataset
# Out:
# ['Ozark',
#  'The Blacklist',
#  'Atypical',
#  'The Blacklist,Ozark',
#  'Mr. Robot',
#  'Deception',
#  'The Walking Dead',
#  'Shadow and Bone',
#  'Demon Slayer',
#  'Ozark,Atypical',
#  'Family Guy',
#  'Berlin Station',
#  'The Blacklist,Atypical',
#  'The Mentalist',
#  'Mr. Robot,Ozark',
#  'Hanna',
#  'Ozark,The Walking Dead',
#  'Family Guy,Ozark',
#  'Family Guy,Atypical',
#  'Daredevil',
#  'Stranger Things',
#  'Outer Banks',
#  '12 Monkeys',
#  'Ozark,Deception',
#  'Ozark,Berlin Station',
#  'The Wire',
#  'Queen of the South',
#  'Two and a half men',
#  'Demon Slayer,The Blacklist',
#  'The Blacklist,Shadow and Bone',
#  'The Blacklist,Ozark,Atypical',
#  'Cobra Kai',
#  'The Blacklist,Mr. Robot',
#  'The Blacklist,Family Guy',
#  'Atypical,Deception',
#  'Ozark,Shadow and Bone',
#  'Family Guy,Ozark,Atypical',
#  'The Blacklist,The Walking Dead',
#  'Mr. Robot,Atypical',
#  'Alice in Borderland',
#  'The Blacklist,Family Guy,Atypical',
#  'The Mentalist,Atypical',
#  'Big Little Lies',
#  'Ozark,The Mentalist',
#  'The Stranger',
#  'Dr. House',
#  '12 Monkeys,The Blacklist',
#  'Demon Slayer,Daredevil',
#  'Family Guy,Deception',
#  'Cobra Kai,Ozark',
#  'The Mentalist,The Wire',
#  'Atypical,Stranger Things',
#  'The Blacklist,Berlin Station',
#  '12 Monkeys,Atypical',
#  'Atypical,Berlin Station',
#  'The Blacklist,Ozark,Family Guy',
#  'Demon Slayer,Ozark',
#  'Dark',
#  'The Mentalist,Deception',
#  'Banshee',
#  'Jack Ryan',
#  'Chernobyl',
#  'The Blacklist,Mr. Robot,Ozark',
#  'The Blacklist,Deception',
#  'The Blacklist,Ozark,Atypical,Family Guy',
#  'Daredevil,Berlin Station',
#  'Ozark,Two and a half men',
#  'The Blacklist,Ozark,The Walking Dead',
#  'The Blacklist,Ozark,Shadow and Bone',
#  'Ozark,The Wire',
#  'Ozark,Stranger Things',
#  'The Blacklist,Stranger Things',
#  'Daredevil,Ozark',
#  'Ozark,Queen of the South',
#  'Family Guy,Berlin Station',
#  'Preacher',
#  'Mr. Robot,Berlin Station',
#  'Spartacus',
#  'Demon Slayer,Atypical',
#  'Succession',
#  'Family Guy,Mr. Robot',
#  'Mr. Robot,Ozark,Atypical',
#  'The Blacklist,Atypical,Deception',
#  'The Walking Dead,Atypical',
#  'Dr. House,Ozark',
#  'Ozark,The Walking Dead,Atypical',
#  'The Blacklist,Mr. Robot,Atypical',
#  'Dr. House,Berlin Station',
#  'The Blacklist,The Wire',
#  'Family Guy,Mr. Robot,Ozark',
#  'Ozark,Atypical,Deception',
#  'The Blacklist,Banshee',
#  'Game of thrones',
#  'The Walking Dead,Shadow and Bone',
#  'Atypical,The Wire',
#  'Demon Slayer,Shadow and Bone',
#  'Sopranos',
#  'Hanna,Ozark',
#  'Ozark,The Mentalist,Atypical',
#  'The Blacklist,The Mentalist',
#  'Outer Banks,Shadow and Bone',
#  'Archer',
#  'Ozark,The Stranger',
#  'Lupin',
#  'Ozark,Jack Ryan',
#  '12 Monkeys,Ozark',
#  'Ozark,Atypical,Berlin Station',
#  'The Blacklist,Alice in Borderland',
#  'Family Guy,Ozark,Deception',
#  'Family Guy,Atypical,Deception',
#  'Jack Ryan,Atypical',
#  '12 Monkeys,Family Guy',
#  'The Blacklist,Daredevil',
#  'The Blacklist,Ozark,Berlin Station',
#  'Berlin Station,Shadow and Bone',
#  'The Blacklist,Queen of the South',
#  'Family Guy,Ozark,Berlin Station',
#  '12 Monkeys,The Blacklist,Atypical',
#  'Family Guy,Atypical,Berlin Station',
#  'The Blacklist,Atypical,Berlin Station',
#  'The Mentalist,Atypical,Deception',
#  'Ozark,Banshee',
#  'Atypical,Alice in Borderland',
#  'Mr. Robot,The Mentalist',
#  'Ozark,Alice in Borderland',
#  'Demon Slayer,The Mentalist',
#  'The Walking Dead,The Mentalist',
#  'The Blacklist,The Mentalist,Atypical',
#  'The Wire,Deception',
#  'Lost in Space',
#  'Ozark,Jack Ryan,Atypical',
#  'The Blacklist,Jack Ryan',
#  'Atypical,Spartacus',
#  'Ozark,The Mentalist,The Wire',
#  'Ozark,Atypical,The Wire',
#  'The Blacklist,Cobra Kai',
#  'Ozark,Chernobyl',
#  'Dr. House,Atypical',
#  'Dr. House,The Blacklist',
#  'The Blacklist,Chernobyl',
#  'Dark,Ozark',
#  'Mr. Robot,Shadow and Bone',
#  "Grey's Anatomy",
#  'The Blacklist,Atypical,Stranger Things',
#  'Two and a half men,Queen of the South',
#  'Mr. Robot,Two and a half men',
#  'Berlin Station,Two and a half men',
#  '12 Monkeys,Family Guy,Atypical',
#  'Demon Slayer,Berlin Station',
#  '12 Monkeys,Stranger Things',
#  'Ozark,Atypical,Stranger Things',
#  'Ozark,Succession',
#  'Daredevil,Shadow and Bone',
#  'The Blacklist,Family Guy,Deception',
#  'The Blacklist,Family Guy,Berlin Station',
#  'Family Guy,Ozark,Atypical,Berlin Station',
#  'The Blacklist,Atypical,Berlin Station,Family Guy',
#  'Family Guy,Mr. Robot,Atypical',
#  'Big Little Lies,Berlin Station',
#  'Demon Slayer,The Blacklist,Atypical',
#  'Only Murders in the building',
#  'Vikings',
#  'Ozark,Outer Banks',
#  'Hanna,Atypical',
#  'Family Guy,Hanna',
#  'The Blacklist,Hanna',
#  'Hanna,Deception',
#  'Demon Slayer,The Blacklist,Shadow and Bone',
#  'The Blacklist,Mr. Robot,Family Guy',
#  'Demon Slayer,The Blacklist,Ozark',
#  'Lost',
#  'The Blacklist,Ozark,Deception',
#  'Demon Slayer,Deception',
#  'One Piece',
#  'Mr. Robot,Deception',
#  'Demon Slayer,Mr. Robot',
#  'Demon Slayer,The Blacklist,Daredevil']

# %%
result = (pd.DataFrame({"itemsets": dataset,
                       "support": frequent_itemsets['support']})).reset_index(drop=True)
result.to_csv('./FPgrowf.csv')
result
# Out:
#                                  itemsets   support
# 0                                   Ozark  0.738095
# 1                           The Blacklist  0.642857
# 2                                Atypical  0.571429
# 3                     The Blacklist,Ozark  0.500000
# 4                               Mr. Robot  0.500000
# ..                                    ...       ...
# 172                Demon Slayer,Deception  0.214286
# 173                             One Piece  0.214286
# 174                   Mr. Robot,Deception  0.214286
# 175                Demon Slayer,Mr. Robot  0.214286
# 176  Demon Slayer,The Blacklist,Daredevil  0.214286
#
# [177 rows x 2 columns]
