# %% [markdown]
# # Association Rules

# %% [markdown]
# # Apriori

# %% [markdown]
# #### Import libraries

# %%
import pandas as pd 
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ## Preprocessing Phase :

# %% [markdown]
# ### Reading the data :

# %%
df = pd.read_csv("Data/TV shows.csv", header = None )
df.describe
# Out:
# <bound method NDFrame.describe of                  0              1                   2                 3   \
# 0         Cobra Kai          Lupin          12 Monkeys          Sherlock
# 1              Lost      Jack Ryan           The Flash   Game of thrones
# 2     Sex Education      Dr. House             Kingdom  The Walking Dead
# 3             Ozark  Sex Education         Constantine          Preacher
# 4            Naruto            NaN                 NaN               NaN
# ...             ...            ...                 ...               ...
# 9685      One Piece  The Blacklist  Two and a half men             Lupin
# 9686      One Piece      Mr. Robot          Succession             Ozark
# 9687      Daredevil       Atypical               Heros               NaN
# 9688       Absentia   The Newsroom        The Alienist               NaN
# 9689       Atypical            NaN                 NaN               NaN
#
#                   4                      5                    6       7   \
# 0                NaN                    NaN                  NaN     NaN
# 1     House of Cards             12 Monkeys              Vikings  Fringe
# 2                NaN                    NaN                  NaN     NaN
# 3            Vikings               The Tick                  NaN     NaN
# 4                NaN                    NaN                  NaN     NaN
# ...              ...                    ...                  ...     ...
# 9685            Dark  How I met your mother                  NaN     NaN
# 9686      12 Monkeys                Vikings  The Vampire Diaries     NaN
# 9687             NaN                    NaN                  NaN     NaN
# 9688             NaN                    NaN                  NaN     NaN
# 9689             NaN                    NaN                  NaN     NaN
#
#                  8             9   ...   22   23   24   25   26   27   28  \
# 0               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1     The Mentalist  The Alienist  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...             ...           ...  ...  ...  ...  ...  ...  ...  ...  ...
# 9685            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9686            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9687            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9688            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9689            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        29   30   31
# 0     NaN  NaN  NaN
# 1     NaN  NaN  NaN
# 2     NaN  NaN  NaN
# 3     NaN  NaN  NaN
# 4     NaN  NaN  NaN
# ...   ...  ...  ...
# 9685  NaN  NaN  NaN
# 9686  NaN  NaN  NaN
# 9687  NaN  NaN  NaN
# 9688  NaN  NaN  NaN
# 9689  NaN  NaN  NaN
#
# [9690 rows x 32 columns]>

# %%
df.isna().sum()
# Out:
# 0        0
# 1     2133
# 2     3743
# 3     5023
# 4     6012
# 5     6853
# 6     7493
# 7     8026
# 8     8459
# 9     8803
# 10    9046
# 11    9226
# 12    9342
# 13    9418
# 14    9494
# 15    9549
# 16    9595
# 17    9624
# 18    9638
# 19    9652
# 20    9661
# 21    9672
# 22    9676
# 23    9682
# 24    9683
# 25    9683
# 26    9684
# 27    9685
# 28    9686
# 29    9689
# 30    9689
# 31    9689
# dtype: int64

# %%
df
# Out:
#                  0              1                   2                 3   \
# 0         Cobra Kai          Lupin          12 Monkeys          Sherlock
# 1              Lost      Jack Ryan           The Flash   Game of thrones
# 2     Sex Education      Dr. House             Kingdom  The Walking Dead
# 3             Ozark  Sex Education         Constantine          Preacher
# 4            Naruto            NaN                 NaN               NaN
# ...             ...            ...                 ...               ...
# 9685      One Piece  The Blacklist  Two and a half men             Lupin
# 9686      One Piece      Mr. Robot          Succession             Ozark
# 9687      Daredevil       Atypical               Heros               NaN
# 9688       Absentia   The Newsroom        The Alienist               NaN
# 9689       Atypical            NaN                 NaN               NaN
#
#                   4                      5                    6       7   \
# 0                NaN                    NaN                  NaN     NaN
# 1     House of Cards             12 Monkeys              Vikings  Fringe
# 2                NaN                    NaN                  NaN     NaN
# 3            Vikings               The Tick                  NaN     NaN
# 4                NaN                    NaN                  NaN     NaN
# ...              ...                    ...                  ...     ...
# 9685            Dark  How I met your mother                  NaN     NaN
# 9686      12 Monkeys                Vikings  The Vampire Diaries     NaN
# 9687             NaN                    NaN                  NaN     NaN
# 9688             NaN                    NaN                  NaN     NaN
# 9689             NaN                    NaN                  NaN     NaN
#
#                  8             9   ...   22   23   24   25   26   27   28  \
# 0               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 1     The Mentalist  The Alienist  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 2               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 3               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 4               NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# ...             ...           ...  ...  ...  ...  ...  ...  ...  ...  ...
# 9685            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9686            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9687            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9688            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
# 9689            NaN           NaN  ...  NaN  NaN  NaN  NaN  NaN  NaN  NaN
#
#        29   30   31
# 0     NaN  NaN  NaN
# 1     NaN  NaN  NaN
# 2     NaN  NaN  NaN
# 3     NaN  NaN  NaN
# 4     NaN  NaN  NaN
# ...   ...  ...  ...
# 9685  NaN  NaN  NaN
# 9686  NaN  NaN  NaN
# 9687  NaN  NaN  NaN
# 9688  NaN  NaN  NaN
# 9689  NaN  NaN  NaN
#
# [9690 rows x 32 columns]

# %% [markdown]
# ### Convert data into a list of lists:

# %%
TVshows = df.values.astype(str).tolist()

# %% [markdown]
# ### Dropping null values

# %%
def remove_items(test_list, item): ## a function that deletes a given element from a list 
    res = [i for i in test_list if i != item] 
    return res

# %%
## Dropping all null values from each list 
for i in range(len(TVshows)):
    TVshows[i] = remove_items(TVshows[i],'nan')
    TVshows[i] = remove_items(TVshows[i],'Sex Education')
TVshows
# Out:
# [['Cobra Kai', 'Lupin', '12 Monkeys', 'Sherlock'],
#  ['Lost',
#   'Jack Ryan',
#   'The Flash',
#   'Game of thrones',
#   'House of Cards',
#   '12 Monkeys',
#   'Vikings',
#   'Fringe',
#   'The Mentalist',
#   'The Alienist',
#   'Big Little Lies',
#   'Chernobyl'],
#  ['Dr. House', 'Kingdom', 'The Walking Dead'],
#  ['Ozark', 'Constantine', 'Preacher', 'Vikings', 'The Tick'],
#  ['Naruto'],
#  [],
#  ['Locke & Key'],
#  ['Lupin'],
#  ['Fringe', 'Shooter', 'How to get away with murder'],
#  ['Queen of the South', 'Better Call Saul', 'Peaky Blinders'],
#  [],
#  ['Atypical', 'Stranger Things', 'Homeland', 'Brooklyn Nine Nine'],
#  ['Daredevil', 'Atypical', 'The Walking Dead', 'The Witcher'],
#  ['One Piece', 'Queen of the South'],
#  ['Demon Slayer',
#   'Atypical',
#   'Stranger Things',
#   'Absentia',
#   'The Alienist',
#   'Chernobyl'],
#  ['Queen of the South',
#   'The Blacklist',
#   'Succession',
#   'Berlin Station',
#   'Atypical',
#   'Two and a half men',
#   'Kingdom',
#   'Orphan Black',
#   'Shooter',
#   'Stranger Things',
#   'The Mentalist',
#   'Absentia',
#   'Banshee',
#   'Designated Survivor'],
#  ['Daredevil',
#   'Lost',
#   'The Boys',
#   'Family Guy',
#   'The man in the high castle',
#   'Dr. House',
#   'Only Murders in the building',
#   'Ragnarok',
#   'Chernobyl',
#   'How I met your mother'],
#  ['Two and a half men',
#   'Only Murders in the building',
#   'Perception',
#   'Lucifer'],
#  ['Preacher',
#   'Only Murders in the building',
#   'Absentia',
#   'Spartacus',
#   'Big Little Lies',
#   'Dark'],
#  ['Lost', 'Gotham'],
#  ['Spartacus', 'Perception'],
#  ['Absentia'],
#  ['Into the night',
#   'Demon Slayer',
#   'Ozark',
#   'Constantine',
#   'Kingdom',
#   'Outer Banks'],
#  ['Hanna',
#   'Demon Slayer',
#   'Ozark',
#   'Berlin Station',
#   'The Walking Dead',
#   'Outer Banks',
#   'Banshee'],
#  ['Daredevil',
#   'The Boys',
#   'Alice in Borderland',
#   'Preacher',
#   'The Outsider',
#   'How to get away with murder',
#   'Spartacus',
#   'The Alienist',
#   'Chernobyl'],
#  ['12 Monkeys', 'Dark', 'How I met your mother'],
#  ['Doctor Who'],
#  ['Doctor Who', 'Mare of Easttown'],
#  ['Outer Banks', 'Brooklyn Nine Nine', 'How I met your mother'],
#  ['Arrow', 'Into the night', 'Queen of the South', 'Ozark', 'Peaky Blinders'],
#  ['The Flash', 'The Wire', 'Kingdom'],
#  ['The Blacklist', 'Ozark', 'You'],
#  ['Absentia'],
#  ['Cobra Kai',
#   'Succession',
#   'Jack Ryan',
#   'Atypical',
#   'Two and a half men',
#   'House of Cards',
#   'Sopranos',
#   'Nine Perfect Strangers',
#   'Absentia'],
#  ['Outer Banks'],
#  ['Demon Slayer', 'Berlin Station', 'Two and a half men', 'Shadow and Bone'],
#  ['Family Guy'],
#  ['Arrow', 'Ozark', 'Deception'],
#  ['Upload', 'The Walking Dead', 'Lupin', 'X-Files', 'Archer'],
#  ['The Outsider', 'Outer Banks'],
#  ['Daredevil', 'Jack Ryan', 'Outer Banks'],
#  ['One Piece',
#   'Berlin Station',
#   'Dr. House',
#   '12 Monkeys',
#   'Sherlock',
#   'How I met your mother'],
#  ['Mirzapur'],
#  ['The Blacklist', 'Rick And Morty', 'Family Guy'],
#  ['Kingdom', 'Rome'],
#  ['The Walking Dead', 'Designated Survivor', 'Goliath'],
#  ['Cobra Kai',
#   'Ozark',
#   'Jack Ryan',
#   'Atypical',
#   'Family Guy',
#   'Preacher',
#   'The Walking Dead',
#   'X-Files',
#   'Only Murders in the building',
#   'Archer',
#   'Banshee',
#   'Perception',
#   'Bojack Horseman',
#   'Chernobyl',
#   'How I met your mother'],
#  ['Ozark', 'Two and a half men'],
#  ['Succession', 'Ozark'],
#  ['The Stranger',
#   'Lost',
#   'Cobra Kai',
#   'The Blacklist',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'House of Cards',
#   'Only Murders in the building',
#   'Perception'],
#  ['The Stranger',
#   'Queen of the South',
#   'Demon Slayer',
#   'Rick And Morty',
#   'Ozark',
#   'Family Guy',
#   'The Originals',
#   'Doctor Who',
#   'Dr. House',
#   'How to get away with murder'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Ozark',
#   'Outer Banks',
#   'Dark',
#   'The Newsroom'],
#  ['Perception', 'Big Little Lies', 'Chernobyl'],
#  ['Alice in Borderland', 'The Walking Dead', 'How I met your mother'],
#  ['Cobra Kai',
#   'Succession',
#   'Emily in Paris',
#   '12 Monkeys',
#   'Dark',
#   'Chernobyl'],
#  ['Demon Slayer'],
#  ['The Walking Dead', 'Vikings', 'Dark', 'Banshee', 'Lucifer'],
#  ['Mare of Easttown'],
#  ['Lost', 'Ozark', 'Deception', 'Doctor Who', 'The Witcher', 'The Mentalist'],
#  ['Haven'],
#  ['Jack Ryan', 'Family Guy', 'Sherlock', 'Archer', 'Banshee'],
#  ['The Blacklist', 'The Night Manager'],
#  ['Supernatural'],
#  ['Constantine', 'Atypical', 'Family Guy', 'Dr Stone', 'The White Lotus'],
#  ['Better Call Saul',
#   'The Walking Dead',
#   'Stranger Things',
#   'Outer Banks',
#   'Mare of Easttown',
#   'The Alienist',
#   'Brooklyn Nine Nine',
#   'Big Little Lies',
#   'Peaky Blinders',
#   'Lucifer'],
#  ['White Collar', 'Outer Banks', 'Hunters', 'Chernobyl'],
#  ['Queen of the South', 'Designated Survivor'],
#  ['Cobra Kai', 'Ozark', 'Deception', 'Vikings'],
#  ['Mr. Robot', 'White Collar', 'Outer Banks'],
#  ['Breaking Bad',
#   'The Wire',
#   'Vikings',
#   'The Witcher',
#   'Outer Banks',
#   'The Mentalist',
#   'The Night Manager',
#   'Lucifer'],
#  ['Ozark'],
#  ['Absentia'],
#  ['Dark'],
#  ['Hanna',
#   'The Wire',
#   'The Blacklist',
#   'The Outsider',
#   'How to get away with murder',
#   'Perception'],
#  ['Hanna', 'The Stranger', 'Kingdom', 'Only Murders in the building'],
#  ['Stranger Things', 'Outer Banks'],
#  ['Lucifer'],
#  ['Shooter', 'Rome', 'How I met your mother', 'Supernatural'],
#  ['Mr. Robot', 'Ozark', 'Atypical', 'Preacher', 'Two and a half men'],
#  ['Dr. House', 'Two and a half men', 'The Mentalist'],
#  ['Outer Banks'],
#  ['The Blacklist', 'Atypical', 'Archer', 'How I met your mother'],
#  ['Outer Banks'],
#  ['Archer', 'Mare of Easttown', 'Dark'],
#  ['Berlin Station',
#   'Alice in Borderland',
#   'Mare of Easttown',
#   'The Mentalist'],
#  ['Daredevil',
#   'The Stranger',
#   'Demon Slayer',
#   'The Boys',
#   'Rick And Morty',
#   'Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Berlin Station',
#   'Family Guy',
#   'The Outsider',
#   'Two and a half men',
#   '12 Monkeys',
#   'Sopranos',
#   'Sherlock',
#   'Stranger Things',
#   'Absentia',
#   'You',
#   'Big Little Lies'],
#  ['Absentia', 'Lucifer'],
#  ['Arrow',
#   'Berlin Station',
#   'Jack Ryan',
#   'Constantine',
#   'Travellers',
#   'Atypical',
#   "Grey's Anatomy",
#   'Kingdom',
#   'The Walking Dead',
#   'The Mentalist',
#   'Shadow and Bone',
#   'Lucifer'],
#  ['Absentia'],
#  ['Inhumans',
#   'The Blacklist',
#   'Demon Slayer',
#   'The Boys',
#   'Jack Ryan',
#   'Family Guy',
#   'Deception',
#   'Punisher'],
#  ['Daredevil',
#   'The Stranger',
#   'Cobra Kai',
#   'Demon Slayer',
#   'Atypical',
#   'Prison Break',
#   'Deception',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead',
#   'Banshee',
#   'Spartacus',
#   'How I met your mother'],
#  ['Mr. Robot', 'Ozark', 'Travellers', 'Two and a half men', 'The Innocent'],
#  ['Berlin Station',
#   'Kingdom',
#   'The Walking Dead',
#   'Mindhunter',
#   'Outer Banks',
#   'How I met your mother'],
#  ['Mr. Robot', '12 Monkeys', 'Stranger Things', 'Outer Banks'],
#  ['The Office', 'Chernobyl'],
#  ['Outer Banks'],
#  ['Atypical', 'Two and a half men', 'The Alienist'],
#  ['Travellers', 'Two and a half men'],
#  ['Two and a half men', 'The Wire', 'Hunters', 'Lucifer'],
#  ['Daredevil',
#   'Family Guy',
#   'House of Cards',
#   'The Umbrella Academy',
#   'The Mentalist'],
#  ['Daredevil', 'Dark', 'The 100'],
#  ['Teen Wolf'],
#  ['Dr. House', 'The Walking Dead', 'Big Little Lies'],
#  ['The Blacklist'],
#  ['Two and a half men', 'Outer Banks'],
#  ['Emily in Paris', 'Two and a half men'],
#  ['Atypical',
#   'Two and a half men',
#   'Dexter',
#   'Outer Banks',
#   'Absentia',
#   'Spartacus'],
#  ['One Piece',
#   'Cobra Kai',
#   'Mr. Robot',
#   'Constantine',
#   'Atypical',
#   'Supergirl',
#   '12 Monkeys',
#   'Lost in Space',
#   'Shadow and Bone',
#   'The Night Manager'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Berlin Station',
#   'Jack Ryan',
#   'Atypical',
#   'Game of thrones',
#   'Stranger Things',
#   'The Tick'],
#  ['The Stranger',
#   'Demon Slayer',
#   'Two and a half men',
#   'Kingdom',
#   'The Walking Dead',
#   'Lupin',
#   '12 Monkeys',
#   'Stranger Things',
#   'How I met your mother'],
#  ['Ozark'],
#  ['Hanna',
#   'Rick And Morty',
#   'Ozark',
#   "Grey's Anatomy",
#   'Dr. House',
#   'Two and a half men',
#   'Kingdom',
#   'The Walking Dead',
#   'Lucifer'],
#  ['Kingdom'],
#  ['The Big Bang Theory', 'Outer Banks', 'Lucifer'],
#  ['His Dark Materials'],
#  ['Absentia'],
#  ['Absentia'],
#  ['The Blacklist',
#   'Ozark',
#   'The Walking Dead',
#   'Banshee',
#   'Spartacus',
#   'Shadow and Bone',
#   'Brooklyn Nine Nine',
#   'Lucifer'],
#  [],
#  ['One Piece', 'Outer Banks', 'Absentia', 'Westworld'],
#  ['Lost',
#   'Person of Interest',
#   'White Collar',
#   'Dr. House',
#   'Only Murders in the building',
#   'Shadow and Bone'],
#  ['Dr. House'],
#  ['Demon Slayer',
#   'The Boys',
#   'Doctor Who',
#   'Two and a half men',
#   'Sopranos',
#   'Absentia',
#   'Euphoria'],
#  ['Two and a half men'],
#  ['Travellers', 'The Flash', 'Archer', 'Shadow and Bone', 'The Night Manager'],
#  ['Atypical',
#   'Dr. House',
#   'Two and a half men',
#   'The Mentalist',
#   'Banshee',
#   'Designated Survivor',
#   'Brooklyn Nine Nine'],
#  ['Demon Slayer',
#   'Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Deception',
#   'The Walking Dead'],
#  ['Outer Banks'],
#  ['12 Monkeys', 'Banshee'],
#  ['The Wire', 'Demon Slayer', 'Ozark', 'Kingdom', 'Sense 8', 'Outer Banks'],
#  ['Lucifer'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Two and a half men',
#   'Archer',
#   'The Mentalist',
#   'The Night Manager'],
#  ['Mr. Robot'],
#  ['24', 'The Mentalist'],
#  ['Daredevil',
#   'Demon Slayer',
#   'Jack Ryan',
#   'Outer Banks',
#   'Absentia',
#   'Haven',
#   'Lucifer'],
#  ['Two and a half men', 'Outer Banks'],
#  ['Emily in Paris', 'Dr. House', 'Mare of Easttown'],
#  ['One Piece', 'Mr. Robot'],
#  ['Banshee', 'The Night Manager'],
#  ['Better Call Saul'],
#  ['Daredevil', 'Two and a half men', 'Outer Banks', 'Shadow and Bone'],
#  ['Mr. Robot', 'Atypical', 'Emily in Paris', 'Game of thrones'],
#  ['Hanna',
#   'The Stranger',
#   'One Piece',
#   'Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Person of Interest',
#   'Ozark',
#   'Travellers',
#   'Emily in Paris',
#   'Alice in Borderland',
#   'Deception',
#   'Sense 8',
#   'House of Cards'],
#  ['Family Guy', 'Deception', 'Game of thrones', 'The Expanse'],
#  ['Arrow',
#   'Cobra Kai',
#   'The Blacklist',
#   'Atypical',
#   'Family Guy',
#   'Outer Banks'],
#  ['Outer Banks'],
#  ['The Walking Dead', 'Outer Banks', 'Brooklyn Nine Nine'],
#  ['Arrow',
#   'Breaking Bad',
#   'Two and a half men',
#   'The Wire',
#   'The Mentalist',
#   'Absentia',
#   'Banshee',
#   'Spartacus',
#   'Shadow and Bone',
#   'Brooklyn Nine Nine'],
#  ['Two and a half men', 'Kingdom', 'Outer Banks'],
#  ['The Wire',
#   'One Piece',
#   'The Wilds',
#   'The Blacklist',
#   'The Boys',
#   'Rick And Morty',
#   'Ozark',
#   'Deception',
#   'Lupin',
#   'Shadow and Bone',
#   'Perception',
#   'His Dark Materials',
#   'Dark'],
#  ['Atypical', '12 Monkeys', 'Stranger Things', 'The Alienist'],
#  ['Daredevil',
#   'The Stranger',
#   'Queen of the South',
#   'Cobra Kai',
#   'The Blacklist',
#   'Mr. Robot',
#   'Succession',
#   'Person of Interest',
#   'Ozark',
#   'Berlin Station',
#   'Jack Ryan',
#   'Atypical',
#   'Doctor Who',
#   'Dr. House'],
#  ['The Umbrella Academy', 'Stranger Things'],
#  [],
#  ['Queen of the South',
#   'Mr. Robot',
#   'Person of Interest',
#   'Ozark',
#   'Berlin Station',
#   'Two and a half men',
#   'Kingdom',
#   'Dark',
#   'Banshee',
#   'Peaky Blinders'],
#  ['Cobra Kai', 'Jack Ryan', 'Travellers', 'The Walking Dead'],
#  ['The Blacklist', '12 Monkeys', 'Vikings'],
#  ['Family Guy', 'The Innocent'],
#  ['Two and a half men'],
#  ['Lost in Space',
#   'Stranger Things',
#   'The Mentalist',
#   'How I met your mother'],
#  ['Daredevil', 'Kingdom', 'Sense 8', 'Archer', 'Hunters'],
#  ['Succession', 'Ozark', 'Game of thrones'],
#  ['Atypical', 'The Flash', 'Two and a half men', 'Stranger Things'],
#  ['Constantine', 'Atypical', '12 Monkeys', 'How I met your mother'],
#  ['Hanna',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Jack Ryan',
#   'Atypical',
#   'White Collar',
#   'The Wire',
#   'The Walking Dead',
#   'Dexter',
#   'Spartacus',
#   'Hunters'],
#  ['The Wilds',
#   'Ozark',
#   'Better Call Saul',
#   'The Witcher',
#   'The Umbrella Academy',
#   'Archer',
#   'Stranger Things',
#   'Locke & Key'],
#  ['The Walking Dead', 'Archer', 'Spartacus'],
#  ['Cobra Kai',
#   'Demon Slayer',
#   'The Boys',
#   'Ozark',
#   'Constantine',
#   'Travellers',
#   'Atypical',
#   'Dr. House',
#   'Game of thrones',
#   'Only Murders in the building',
#   'Vikings',
#   'Sons of Anarchy',
#   'Perception',
#   'Hunters'],
#  ['One Piece',
#   'Mr. Robot',
#   'Person of Interest',
#   'Deception',
#   'Two and a half men',
#   'Mindhunter',
#   'Perception',
#   'The Expanse'],
#  ['Lost', 'Sons of Anarchy'],
#  ['Absentia'],
#  ['The Walking Dead'],
#  ['Better Call Saul', 'Constantine', 'Lupin', 'Absentia'],
#  ['Outer Banks'],
#  ['Daredevil',
#   'Two and a half men',
#   'Outer Banks',
#   'Absentia',
#   'Brooklyn Nine Nine',
#   'Lucifer'],
#  ['Demon Slayer',
#   'Dr. House',
#   'The Wire',
#   'Game of thrones',
#   'Inside Job',
#   'Punisher',
#   'Stranger Things',
#   'The Mentalist',
#   'The Expanse'],
#  ['Shadow and Bone'],
#  ['The Outsider', 'Archer', 'Spartacus'],
#  ['Dark'],
#  ['Jack Ryan',
#   'Doctor Who',
#   'The Walking Dead',
#   'Banshee',
#   'Spartacus',
#   'Chernobyl'],
#  ['Travellers', 'Black Clover'],
#  ['Archer'],
#  ['The Blacklist', 'Family Guy', 'The Nevers'],
#  ['The Blacklist', "Grey's Anatomy", 'Two and a half men', 'Shadow and Bone'],
#  ['Daredevil', 'Heros', 'Preacher', 'Absentia'],
#  ['Daredevil',
#   'Mr. Robot',
#   'Ozark',
#   'Only Murders in the building',
#   'Sopranos',
#   'Designated Survivor',
#   'How I met your mother'],
#  ['Ozark', 'The Wire', 'The Alienist'],
#  ['The Stranger',
#   'The Blacklist',
#   'Demon Slayer',
#   'Ozark',
#   'Atypical',
#   'The Walking Dead',
#   'Dark',
#   'Locke & Key'],
#  ['Archer'],
#  ['Hunters'],
#  ['Arrow',
#   'The Blacklist',
#   'Nine Perfect Strangers',
#   'Outer Banks',
#   'Absentia'],
#  ['Doctor Who'],
#  ['Cobra Kai',
#   'Atypical',
#   'White Collar',
#   'The Walking Dead',
#   'Orphan Black',
#   'Archer',
#   'Elite'],
#  ['Dr. House',
#   'The Walking Dead',
#   'Dark',
#   'Absentia',
#   'Banshee',
#   'Shadow and Bone',
#   'Dark',
#   'How I met your mother'],
#  ['Person of Interest'],
#  ['The Blacklist',
#   'Atypical',
#   'Two and a half men',
#   'The Walking Dead',
#   'Archer',
#   'Designated Survivor'],
#  ['Only Murders in the building', 'The Night Manager'],
#  ['One Piece', 'Stranger Things', 'Dark'],
#  ['Ozark', 'Shadow and Bone'],
#  ['Kingdom'],
#  ['The Blacklist',
#   'Family Guy',
#   'White Collar',
#   'The Innocent',
#   'House of Cards',
#   'Only Murders in the building',
#   'How to get away with murder',
#   'The Night Manager'],
#  ['One Piece',
#   'Ozark',
#   'Atypical',
#   'The Wire',
#   'Dark',
#   'Chernobyl',
#   'Lucifer'],
#  ['Hunters', 'Love Death Robots', 'Big Little Lies', 'Chernobyl'],
#  ['The Stranger', 'Rick And Morty', 'Deception', 'Archer', 'The IT Crowd'],
#  ['One Piece', 'The Wilds', 'Cobra Kai', 'Banshee'],
#  ['Better Call Saul', 'Stranger Things'],
#  ['The Blacklist',
#   'Mr. Robot',
#   'Jack Ryan',
#   'Atypical',
#   'Deception',
#   'Dr. House'],
#  ['The Blacklist',
#   'Two and a half men',
#   'Sherlock',
#   'How to get away with murder',
#   'Brooklyn Nine Nine'],
#  ['Daredevil',
#   'Two and a half men',
#   'Outer Banks',
#   'How to get away with murder',
#   'Banshee',
#   'Spartacus',
#   'Outlander',
#   'The Night Manager'],
#  ['Demon Slayer'],
#  ['The Flash', 'The Walking Dead', 'Suits', 'Peaky Blinders'],
#  ['Ozark', 'Atypical', 'Family Guy', 'How I met your mother'],
#  ['Mr. Robot', 'Ozark', 'Friends', 'Suits', 'Lucifer'],
#  ['Daredevil',
#   'Arrow',
#   'Queen of the South',
#   'Mr. Robot',
#   'White Collar',
#   'The Umbrella Academy',
#   'Outer Banks'],
#  ['One Piece', 'Queen of the South', 'Better Call Saul', 'The Walking Dead'],
#  ['Mr. Robot', 'Ozark', 'The Big Bang Theory', 'Dark'],
#  ['Ozark',
#   'Preacher',
#   'The Wire',
#   'The Nevers',
#   'Archer',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia',
#   'Locke & Key',
#   'The IT Crowd'],
#  [],
#  ['Ozark',
#   'The Walking Dead',
#   'Game of thrones',
#   '12 Monkeys',
#   'Black Clover',
#   'Banshee',
#   'Shadow and Bone'],
#  ['The Stranger',
#   'Rick And Morty',
#   'Mr. Robot',
#   'Person of Interest',
#   'Ozark',
#   'Jack Ryan',
#   'The Outsider',
#   'Dr. House',
#   '12 Monkeys',
#   'The Big Bang Theory',
#   'How I met your mother'],
#  ['Daredevil',
#   'Demon Slayer',
#   'Two and a half men',
#   'The Walking Dead',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia',
#   'How to get away with murder',
#   'The Night Manager',
#   'Big Little Lies'],
#  ['Cobra Kai',
#   'Constantine',
#   'Atypical',
#   'White Collar',
#   'Deception',
#   'Supergirl',
#   'Mirzapur',
#   'The Vampire Diaries',
#   'Spartacus'],
#  ['How I met your mother'],
#  ['Daredevil', 'The Wire', 'The Blacklist', 'Preacher'],
#  ['The Blacklist', 'Travellers', 'Kingdom', 'Game of thrones'],
#  ['Daredevil',
#   'Ozark',
#   'Constantine',
#   'Dr. House',
#   'The Walking Dead',
#   'Chernobyl'],
#  ['Outer Banks', 'Ragnarok'],
#  ['Atypical', 'Stranger Things', 'Absentia', 'Chernobyl'],
#  ['Daredevil',
#   'Cobra Kai',
#   'Demon Slayer',
#   'Jack Ryan',
#   'Dr. House',
#   '12 Monkeys',
#   'How I met your mother'],
#  ['Emily in Paris'],
#  ['Demon Slayer', 'Mr. Robot', 'Mirzapur', 'The Mentalist', 'Peaky Blinders'],
#  ['Inhumans',
#   'Cobra Kai',
#   'Ozark',
#   'Jack Ryan',
#   "The Queen's Gambit",
#   'Lupin',
#   'Schitts Creek'],
#  ['The Mentalist'],
#  ['Preacher'],
#  ['Arrow',
#   'The Wire',
#   'Constantine',
#   'Travellers',
#   'Family Guy',
#   'Alice in Borderland',
#   'Two and a half men',
#   'Outer Banks',
#   'The Mentalist'],
#  ['Hanna',
#   'Inhumans',
#   'Demon Slayer',
#   'Atypical',
#   'Emily in Paris',
#   'Preacher',
#   'Deception',
#   'Doctor Who',
#   'Kingdom',
#   'The Walking Dead',
#   'Sacred Games',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'The White Lotus'],
#  ['The Night Manager'],
#  ['Hanna', 'Two and a half men', 'Shadow and Bone'],
#  ['Archer'],
#  ['Lost',
#   'The Blacklist',
#   'Person of Interest',
#   'Ozark',
#   'Jack Ryan',
#   'The Outsider',
#   'Fringe',
#   'How I met your mother',
#   'Lucifer'],
#  ['Mare of Easttown'],
#  ['Lost', 'Demon Slayer', 'Ozark', 'Jack Ryan', 'Sense 8'],
#  ['Jack Ryan'],
#  ['Iron Fist'],
#  ['Mare of Easttown', 'Haven'],
#  ['The Stranger', 'Banshee', 'Shadow and Bone'],
#  ['The man in the high castle', 'Two and a half men', 'Kingdom'],
#  ['Better Call Saul'],
#  ['One Piece', 'Ozark', 'Sacred Games'],
#  ['Two and a half men'],
#  ['Two and a half men', 'Dark'],
#  ['Outer Banks'],
#  ['Love Death Robots'],
#  ['Succession'],
#  ['Jack Ryan', 'Preacher', 'Lucifer'],
#  ['Mindhunter', 'Big Little Lies', 'Startup'],
#  ["The Handmaid's Tale"],
#  ['The Blacklist',
#   'Jack Ryan',
#   'Alice in Borderland',
#   'Two and a half men',
#   'Outer Banks'],
#  ['The Blacklist', 'Ozark', 'Atypical'],
#  ['White Collar', 'Kingdom', 'Sopranos', 'Archer', 'Outer Banks', 'Hunters'],
#  ['Hanna', 'The Stranger', 'The Outsider', 'Two and a half men'],
#  ['Two and a half men', 'Stranger Things'],
#  ['Atypical',
#   'Emily in Paris',
#   'The Mentalist',
#   'Perception',
#   'Bojack Horseman'],
#  ['Daredevil'],
#  ['Demon Slayer'],
#  ['Into the night',
#   'Atypical',
#   'Two and a half men',
#   'The Walking Dead',
#   '12 Monkeys',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia'],
#  ['Demon Slayer',
#   'Prison Break',
#   'Black Clover',
#   'Mare of Easttown',
#   'The Mentalist',
#   'The Night Manager'],
#  ['Berlin Station', 'The Outsider', 'Kingdom', 'Dark', "The Queen's Gambit"],
#  ['Hanna', 'Two and a half men', 'The Innocent'],
#  ['Queen of the South', 'The Blacklist', '12 Monkeys', 'Outer Banks', 'Dark'],
#  ['Stranger Things', 'Designated Survivor'],
#  ['Daredevil',
#   'Constantine',
#   'Dr. House',
#   'Two and a half men',
#   'Outer Banks',
#   'Dark',
#   'Locke & Key',
#   'How to get away with murder',
#   'Chernobyl'],
#  ['Outer Banks', 'Designated Survivor', 'Lucifer'],
#  ['Outer Banks'],
#  ['Spartacus'],
#  ['Mare of Easttown'],
#  ['Queen of the South', "Grey's Anatomy", 'Dark'],
#  ['Queen of the South', 'Mr. Robot', 'Big Little Lies'],
#  ['Ozark', 'Supergirl', 'The Wire', 'Lost in Space', 'Banshee'],
#  ['Daredevil', 'Two and a half men', 'Outer Banks'],
#  ['Euphoria'],
#  ['Absentia', 'Brooklyn Nine Nine'],
#  ['Ozark', 'The Mentalist', 'How to get away with murder', 'Chernobyl'],
#  ['Rome'],
#  ['Elementary', 'Ozark', 'Deception', 'Dark'],
#  ['Demon Slayer', 'Travellers', 'Outer Banks'],
#  ['Queen of the South', 'Mr. Robot'],
#  ['Absentia', 'Lucifer'],
#  ['Chernobyl'],
#  ['Outer Banks', 'The Alienist'],
#  ['Prison Break', 'Upload'],
#  ['Outer Banks', 'The Office'],
#  ['Cobra Kai', 'Squid Game'],
#  ['Mirzapur', 'Banshee', 'The Wheel of Time'],
#  ['Ozark',
#   'Travellers',
#   'Atypical',
#   'Preacher',
#   'Dr. House',
#   'Two and a half men',
#   'Kingdom',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia',
#   'Locke & Key',
#   'Banshee',
#   'Shadow and Bone',
#   'Lucifer'],
#  ['Atypical', 'White Collar', 'Two and a half men'],
#  ['Daredevil', 'Alice in Borderland', 'Lost in Space'],
#  ['The Wire', 'Banshee', 'Lucifer'],
#  ['Queen of the South',
#   'Lost',
#   'Rick And Morty',
#   'The Walking Dead',
#   'Big Little Lies'],
#  ['Riverdale',
#   'The 100',
#   'The Newsroom',
#   'Banshee',
#   'Hunters',
#   'Chernobyl',
#   'The Tick',
#   'Lucifer'],
#  ['Arrow', 'One Piece', 'Lucifer'],
#  ['Ozark'],
#  ['Dark'],
#  ['Rome'],
#  ['The Blacklist', 'Demon Slayer', 'Atypical'],
#  ['Archer', 'Big Little Lies'],
#  ['Demon Slayer', 'Stranger Things'],
#  ['The Blacklist', 'Demon Slayer', 'Outer Banks', 'Rome'],
#  ['Ozark',
#   'The man in the high castle',
#   'Kingdom',
#   'Lupin',
#   'The Innocent',
#   'Shooter'],
#  ['Lost'],
#  ['Two and a half men', 'Kingdom', 'Absentia'],
#  ['Cobra Kai',
#   'Mr. Robot',
#   'Better Call Saul',
#   'Atypical',
#   'Alice in Borderland',
#   'Two and a half men',
#   'The Wire',
#   'Kingdom',
#   'Mirzapur'],
#  ['Dark'],
#  ['Ozark',
#   'Deception',
#   'Lupin',
#   'X-Files',
#   'Nine Perfect Strangers',
#   'How to get away with murder',
#   'Banshee',
#   'Peaky Blinders'],
#  ['Daredevil', 'Ozark', 'Alice in Borderland', 'Sopranos', 'The Mentalist'],
#  ['Berlin Station',
#   'Atypical',
#   'Kingdom',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Banshee',
#   'How I met your mother'],
#  ['Haven', 'How I met your mother'],
#  ['Hanna',
#   'One Piece',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Ozark',
#   'Travellers',
#   'Atypical',
#   'Preacher',
#   'Two and a half men',
#   'Kingdom',
#   'Outer Banks'],
#  ['Daredevil',
#   'The Blacklist',
#   'Ozark',
#   'Deception',
#   'Two and a half men',
#   'The Wire',
#   'Kingdom',
#   'Sense 8',
#   'Only Murders in the building',
#   'Vikings'],
#  ['Hanna',
#   'Cobra Kai',
#   'Dr. House',
#   'Only Murders in the building',
#   'Friends',
#   'Designated Survivor',
#   'How I met your mother'],
#  [],
#  ['Mr. Robot'],
#  ['Ozark', 'Doctor Who', 'Designated Survivor'],
#  ['The Boys'],
#  [],
#  ['The Blacklist', 'Lucifer'],
#  ['Hanna',
#   'Ozark',
#   'Jack Ryan',
#   'Supergirl',
#   'Dr. House',
#   '12 Monkeys',
#   'Homeland',
#   'Dark',
#   'Absentia'],
#  ['Hanna',
#   'The Blacklist',
#   'Mr. Robot',
#   'Jack Ryan',
#   'Constantine',
#   'Deception',
#   'The Walking Dead',
#   'Dexter',
#   'Homeland',
#   'How I met your mother'],
#  ['Atypical', 'Two and a half men', 'Mare of Easttown'],
#  ['Cobra Kai',
#   'Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Dr. House',
#   'The Wire',
#   'Haven'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Rick And Morty',
#   'Ozark',
#   'Family Guy',
#   "Grey's Anatomy",
#   'Kingdom',
#   'Mirzapur',
#   'The Big Bang Theory',
#   'Inside Job',
#   'Archer',
#   'How I met your mother',
#   'Lucifer'],
#  ['Arrow',
#   'Cobra Kai',
#   'Travellers',
#   'Atypical',
#   'Preacher',
#   'Two and a half men',
#   'Nine Perfect Strangers',
#   'Goliath',
#   'Chernobyl',
#   'Peaky Blinders'],
#  ['Ozark', 'Kingdom', 'The Vampire Diaries', 'Rome'],
#  ['The Alienist'],
#  ['Ozark',
#   'The man in the high castle',
#   'Only Murders in the building',
#   'Lucifer'],
#  ['Gotham'],
#  ['The Boys', 'Mare of Easttown', 'The Mentalist'],
#  ['Elementary',
#   'The Stranger',
#   'Mr. Robot',
#   'Travellers',
#   'Kingdom',
#   'The Mentalist'],
#  ['Atypical', 'Stranger Things'],
#  ['Dr. House',
#   'Two and a half men',
#   'Archer',
#   'Absentia',
#   'Riverdale',
#   'Shadow and Bone',
#   'Lucifer'],
#  ['Absentia'],
#  ['Deception'],
#  ['Ozark', 'Two and a half men', 'Kingdom'],
#  ['Dark',
#   'Riverdale',
#   'Sneaky Pete',
#   'Shadow and Bone',
#   'Designated Survivor',
#   'Lucifer'],
#  ['Gotham'],
#  ['Daredevil',
#   'Cobra Kai',
#   'The Blacklist',
#   'Stranger Things',
#   'Brooklyn Nine Nine',
#   'Perception',
#   'How I met your mother'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Mr. Robot',
#   'Atypical',
#   'Shooter',
#   'Stranger Things',
#   'Outer Banks',
#   'The Good Doctor'],
#  ['The Blacklist', 'Preacher', 'Shadow and Bone'],
#  ['The Alienist', 'Brooklyn Nine Nine'],
#  ['Ozark',
#   'Doctor Who',
#   'Two and a half men',
#   'Stranger Things',
#   'Dark',
#   'Locke & Key'],
#  ['The Witcher', 'Shadow and Bone', 'Designated Survivor'],
#  ['Daredevil', 'Two and a half men', 'The Mentalist'],
#  ['The Walking Dead'],
#  ['Mr. Robot', 'Dr. House', '12 Monkeys', 'Outlander', 'The Night Manager'],
#  ['Outer Banks', 'Dark', 'The 100', 'Locke & Key'],
#  ['The Wire',
#   'One Piece',
#   'Succession',
#   "The Queen's Gambit",
#   'Dr. House',
#   'The Wire',
#   'Game of thrones',
#   'The Innocent',
#   'Dark'],
#  ['Ozark',
#   'Supergirl',
#   'Lost in Space',
#   'Nine Perfect Strangers',
#   'How to get away with murder',
#   'Lucifer'],
#  ['Outer Banks'],
#  ['The Wire'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Rick And Morty',
#   'The Outsider',
#   'The Wire'],
#  ['Daredevil',
#   'Cobra Kai',
#   'Ozark',
#   'Dr Stone',
#   'Punisher',
#   'Stranger Things',
#   'Perception',
#   'How I met your mother'],
#  ['Hanna',
#   'Into the night',
#   'The Blacklist',
#   'The Boys',
#   'Mr. Robot',
#   'Ozark',
#   'Deception',
#   'Doctor Who',
#   'The man in the high castle',
#   'The Walking Dead',
#   'Lost in Space',
#   'Mindhunter',
#   'Outer Banks',
#   'Mare of Easttown',
#   'How to get away with murder',
#   'Haven',
#   'Shadow and Bone',
#   'Perception',
#   'Startup'],
#  ['Nine Perfect Strangers', 'The Umbrella Academy', 'Lucifer'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'The Flash',
#   'Doctor Who',
#   'The Wire',
#   'Mirzapur',
#   'Friends',
#   'The Good Doctor',
#   'Big Little Lies',
#   'How I met your mother'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Family Guy',
#   'Two and a half men',
#   'The Night Manager',
#   'How I met your mother'],
#  ['Queen of the South', 'The Blacklist', 'Atypical'],
#  ['Outer Banks', 'Dark', 'The 100', 'Locke & Key', 'Chernobyl'],
#  ['One Piece', 'Stranger Things', 'Rome'],
#  ['Lost',
#   'Mr. Robot',
#   'Atypical',
#   'Kingdom',
#   'The Walking Dead',
#   'Dark',
#   'Designated Survivor',
#   'The Expanse'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Rick And Morty',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Stranger Things',
#   'South Park',
#   'Big Little Lies',
#   'Chernobyl'],
#  ['Daredevil',
#   'Cobra Kai',
#   'Outer Banks',
#   'The Mentalist',
#   'How to get away with murder',
#   'Chernobyl',
#   'The IT Crowd'],
#  ['Outer Banks'],
#  ['The Blacklist', 'Two and a half men', 'The Walking Dead'],
#  ['One Piece', 'Absentia', 'Ragnarok'],
#  ['Two and a half men', 'Kingdom', 'The Walking Dead', 'Archer', 'Dark'],
#  ['Billions', 'Two and a half men', 'Archer', 'How to get away with murder'],
#  ['Absentia', 'Lucifer'],
#  ['Breaking Bad',
#   'Outer Banks',
#   'Dark',
#   'The 100',
#   'Locke & Key',
#   'Chernobyl'],
#  ['The Office'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Prison Break',
#   'Doctor Who',
#   '24',
#   'Black Clover',
#   'Archer',
#   'Absentia',
#   'How to get away with murder',
#   'The IT Crowd',
#   'The White Lotus',
#   'Lucifer'],
#  ['Two and a half men', '12 Monkeys', 'How I met your mother'],
#  ['Constantine', 'Designated Survivor'],
#  ['Cobra Kai', 'Ozark', 'Berlin Station', 'Two and a half men'],
#  ["Grey's Anatomy", 'Outer Banks', 'Rome'],
#  ['The Witcher'],
#  ['Daredevil',
#   'Alice in Borderland',
#   'Two and a half men',
#   'Vikings',
#   'The Night Manager'],
#  ['Hanna', 'Mr. Robot', 'Succession', 'Ozark', 'The Wire', 'Absentia'],
#  ['Family Guy',
#   'Lupin',
#   'Punisher',
#   'Lost in Space',
#   'Stranger Things',
#   'Outer Banks',
#   'Chernobyl'],
#  ['Outer Banks'],
#  ['Inhumans',
#   'Queen of the South',
#   'Demon Slayer',
#   'Better Call Saul',
#   'The Walking Dead',
#   '12 Monkeys'],
#  ['Daredevil', 'Madmen', 'Dr. House', 'Outer Banks', 'Lucifer'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Atypical',
#   'The Outsider',
#   'Outer Banks'],
#  ['Hanna',
#   'Demon Slayer',
#   'Succession',
#   'Jack Ryan',
#   'Atypical',
#   'The Walking Dead',
#   'Fringe',
#   'His Dark Materials'],
#  ['Shooter'],
#  ['House of Cards', 'Outer Banks', 'Squid Game', 'Haven'],
#  ['The Stranger',
#   'Atypical',
#   'Family Guy',
#   'Upload',
#   'Outer Banks',
#   'Peaky Blinders'],
#  ['The Wire',
#   'One Piece',
#   'Mr. Robot',
#   'Ozark',
#   'Atypical',
#   'Preacher',
#   'Two and a half men',
#   'The Wire',
#   'X-Files',
#   'Outer Banks',
#   'Haven',
#   'Chernobyl'],
#  ['Into the night',
#   'The Blacklist',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Ozark',
#   'Jack Ryan',
#   'Travellers',
#   'Atypical',
#   'Invincible',
#   'Locke & Key',
#   'X-Files',
#   '12 Monkeys'],
#  ['Daredevil', 'Stranger Things'],
#  ['Hanna', 'Daredevil', 'Supergirl', '12 Monkeys', 'Brooklyn Nine Nine'],
#  ['Daredevil', 'Stranger Things', 'Rome'],
#  ['White Collar',
#   'Archer',
#   'Absentia',
#   'Designated Survivor',
#   'The Night Manager'],
#  ['Rome'],
#  ['Brooklyn Nine Nine'],
#  ['Arrow',
#   'The Boys',
#   'Madmen',
#   'The Outsider',
#   'The man in the high castle',
#   'The Wire',
#   'Only Murders in the building',
#   'Sherlock'],
#  ['Demon Slayer',
#   'Mr. Robot',
#   'White Collar',
#   'Prison Break',
#   '12 Monkeys',
#   'Vikings',
#   'Sherlock',
#   'Space Force',
#   'The Mentalist',
#   'Shadow and Bone'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Preacher',
#   'Deception',
#   'The Outsider',
#   'Stranger Things',
#   'Lucifer'],
#  ['Daredevil',
#   'The Stranger',
#   'Breaking Bad',
#   'Deception',
#   'Two and a half men',
#   'Locke & Key',
#   '12 Monkeys',
#   'Vikings',
#   'Altered Carbon',
#   'Lost in Space',
#   'Big Little Lies'],
#  ['Rick And Morty',
#   'Mr. Robot',
#   'Jack Ryan',
#   'Supergirl',
#   'Dr. House',
#   'Two and a half men'],
#  ['The Blacklist', 'Archer', 'The Night Manager', 'The Office', 'Lucifer'],
#  ['The Boys',
#   'Rick And Morty',
#   'Berlin Station',
#   'Deception',
#   'Stranger Things',
#   'Outer Banks',
#   'The IT Crowd'],
#  ['Jack Ryan', 'Emily in Paris', 'The Walking Dead', 'Peaky Blinders'],
#  ['Shooter'],
#  ['Hanna', 'Two and a half men', 'The Tick', 'Lucifer'],
#  ['Constantine',
#   'Atypical',
#   'Kingdom',
#   'The Walking Dead',
#   'Outer Banks',
#   'Banshee',
#   'Haven',
#   'Elite'],
#  ['Hanna', 'Mr. Robot', 'How I met your mother'],
#  ['Daredevil', 'Outer Banks', 'Dark'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'The Boys',
#   'Mr. Robot',
#   'Person of Interest',
#   'Atypical',
#   'Punisher',
#   'Ragnarok',
#   'Peaky Blinders',
#   'Lucifer'],
#  ['Cobra Kai',
#   'Ozark',
#   'Atypical',
#   'Madmen',
#   'Two and a half men',
#   'Outer Banks',
#   'Shadow and Bone',
#   'How I met your mother'],
#  ['Daredevil', 'Absentia'],
#  ['Preacher', 'Archer'],
#  ['Lost', 'Deception'],
#  ['Emily in Paris', 'Stranger Things', 'Mare of Easttown'],
#  ['Hanna',
#   'The Wire',
#   'The Blacklist',
#   'Succession',
#   'Only Murders in the building',
#   'Punisher',
#   'Homeland',
#   'The IT Crowd'],
#  ['One Piece', 'Ozark', 'Jack Ryan'],
#  ['Friends'],
#  ['Constantine', 'Alice in Borderland', 'The Flash', 'The Wire', 'Kingdom'],
#  ['Two and a half men'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Atypical',
#   'Two and a half men',
#   'The Walking Dead',
#   'Lupin',
#   'Dark',
#   'Chernobyl'],
#  ['Arrow', 'Ozark', 'The Flash', 'The Walking Dead', 'The Alienist'],
#  ['Two and a half men', 'How I met your mother'],
#  ['Absentia'],
#  ['Supernatural'],
#  ['Absentia'],
#  ['The Mentalist', 'Peaky Blinders', 'Lucifer'],
#  ['The Wire', 'One Piece', 'The Blacklist', 'Mr. Robot', 'Ozark'],
#  ['Queen of the South',
#   'Cobra Kai',
#   'Locke & Key',
#   'Nine Perfect Strangers',
#   'Outer Banks',
#   'The Mentalist',
#   'The Tick',
#   'Lucifer'],
#  ['Demon Slayer',
#   'Atypical',
#   'Alice in Borderland',
#   'Deception',
#   'Dr. House',
#   'Lost in Space',
#   'Inside Job',
#   'Goliath',
#   'Chernobyl'],
#  ['The Wire', 'The Flash', 'Dark'],
#  ['Arrow',
#   'Constantine',
#   'Breaking Bad',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Shadow and Bone'],
#  ['Outer Banks', 'Mare of Easttown'],
#  ['Dark', 'The 100'],
#  ['The Wire', 'Two and a half men', 'Outer Banks'],
#  ['Rick And Morty', 'Atypical', 'Vikings', 'The IT Crowd', 'Startup'],
#  ['Outer Banks', 'Absentia'],
#  ['Queen of the South',
#   'Cobra Kai',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead',
#   'Sense 8',
#   'Homeland',
#   'The Mentalist'],
#  ['Rick And Morty', 'Family Guy'],
#  ['The Wire',
#   'Cobra Kai',
#   'The Blacklist',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Atypical',
#   'Alice in Borderland',
#   'Deception',
#   'Locke & Key',
#   'Fringe',
#   'Punisher',
#   'Stranger Things',
#   'Homeland',
#   'Goliath',
#   'Gotham'],
#  ['Inhumans',
#   'Mr. Robot',
#   'Ozark',
#   'Breaking Bad',
#   'The Walking Dead',
#   'Vikings',
#   'Perception'],
#  ['Shadow and Bone', 'The Night Manager'],
#  ['Gotham'],
#  ['Jack Ryan', 'Atypical', 'Dr. House', 'The Wire', 'Dexter', 'Banshee'],
#  ['Stranger Things', 'The Night Manager'],
#  ['The Stranger',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Atypical',
#   'Dr Stone',
#   'Dr. House',
#   'The Walking Dead',
#   'Locke & Key',
#   'Black Clover',
#   'Mare of Easttown',
#   'Perception',
#   'Startup'],
#  ['Dark'],
#  ['Doctor Who', 'Outer Banks', 'Designated Survivor'],
#  ['The Big Bang Theory', 'Westworld'],
#  ['Daredevil',
#   'Lost',
#   'The Blacklist',
#   'Mr. Robot',
#   'White Collar',
#   'Dr. House',
#   'Two and a half men',
#   'Lupin',
#   '12 Monkeys',
#   'Lost in Space',
#   'Outer Banks',
#   'The Mentalist'],
#  ['The Blacklist',
#   'Prison Break',
#   'Nine Perfect Strangers',
#   'Stranger Things',
#   'The Mentalist',
#   'Designated Survivor'],
#  ['Demon Slayer', 'Rick And Morty', 'Mr. Robot', 'Ozark', 'Family Guy'],
#  ['Archer'],
#  ['The Night Manager'],
#  ['Daredevil', 'Two and a half men'],
#  ['Daredevil', 'Rick And Morty', 'Alice in Borderland', 'Preacher'],
#  ['Cobra Kai'],
#  ['Atypical', 'Emily in Paris', 'Stranger Things', 'Brooklyn Nine Nine'],
#  ['Dark', 'Lucifer'],
#  ['The Stranger',
#   'Ozark',
#   'Dr. House',
#   'Only Murders in the building',
#   '12 Monkeys',
#   'Vikings',
#   'Archer',
#   'Dark',
#   'Brooklyn Nine Nine',
#   'The Night Manager'],
#  ['Mare of Easttown',
#   'The Mentalist',
#   'Absentia',
#   'The Alienist',
#   'Shadow and Bone',
#   'Lucifer'],
#  ['Outer Banks', 'Absentia'],
#  ['Demon Slayer', 'Family Guy'],
#  ['One Piece',
#   'Demon Slayer',
#   'Ozark',
#   'Travellers',
#   'The Wire',
#   'The Walking Dead',
#   'Outer Banks',
#   'The Mentalist'],
#  ['Jack Ryan',
#   'The Wire',
#   'The Walking Dead',
#   'Outer Banks',
#   'How to get away with murder',
#   'Suits',
#   'Spartacus',
#   'The Alienist',
#   'Shadow and Bone',
#   'Designated Survivor'],
#  [],
#  ['Demon Slayer',
#   'Ozark',
#   'Berlin Station',
#   'Atypical',
#   'Family Guy',
#   'Kingdom',
#   'The Walking Dead',
#   'The Mentalist',
#   'Perception'],
#  ['Cobra Kai', 'Archer', 'Absentia', 'The Alienist', 'Lucifer'],
#  ['Queen of the South', 'The Boys', 'Perception'],
#  ['Queen of the South',
#   'The Blacklist',
#   'Ozark',
#   'Preacher',
#   'Two and a half men',
#   'Sopranos',
#   'Stranger Things',
#   'Locke & Key',
#   'The Tick'],
#  ['Kingdom', 'Stranger Things', 'Outer Banks', 'Absentia'],
#  ['Gotham'],
#  ['Family Guy', 'White Collar', 'Dr. House'],
#  ['The Blacklist'],
#  ['Person of Interest'],
#  ['The Wire',
#   'One Piece',
#   'The Blacklist',
#   'Rick And Morty',
#   'Punisher',
#   'Black Clover',
#   'Ragnarok'],
#  ['How I met your mother'],
#  ['Cobra Kai',
#   'Rick And Morty',
#   'Ozark',
#   'Doctor Who',
#   'How I met your mother'],
#  ['Succession',
#   'Ozark',
#   "Grey's Anatomy",
#   'The Flash',
#   "The Queen's Gambit",
#   'Designated Survivor'],
#  ['House of Cards', 'Suits'],
#  ['Cobra Kai',
#   'Rick And Morty',
#   'Ozark',
#   'Constantine',
#   'Family Guy',
#   'Preacher',
#   'Stranger Things'],
#  ['Altered Carbon', '24', 'Stranger Things'],
#  ['Lost',
#   'Preacher',
#   'Mindhunter',
#   'Archer',
#   'Absentia',
#   'The IT Crowd',
#   'Lucifer'],
#  ['Queen of the South',
#   'Cobra Kai',
#   'The Boys',
#   'Mr. Robot',
#   'Two and a half men',
#   'Nine Perfect Strangers',
#   'Shadow and Bone'],
#  ['Mare of Easttown'],
#  ['Hanna', 'Cobra Kai', 'Shooter', 'Archer'],
#  ['Two and a half men', 'Sense 8', 'Mirzapur', 'Dark'],
#  ['Hanna',
#   'Daredevil',
#   'The Blacklist',
#   'Mr. Robot',
#   'Alice in Borderland',
#   'Deception',
#   'Sopranos',
#   'Lost in Space',
#   'How to get away with murder'],
#  ['Cobra Kai', 'Mr. Robot', '12 Monkeys', 'The Witcher', 'Lucifer'],
#  ['Stranger Things', 'The Mentalist'],
#  ['The Wire',
#   'The Stranger',
#   'Rick And Morty',
#   'Atypical',
#   'Family Guy',
#   'Preacher',
#   'True Detective',
#   'Kingdom',
#   'Banshee'],
#  ['Arrow',
#   'The Stranger',
#   'Cobra Kai',
#   'Ozark',
#   'Atypical',
#   'Family Guy',
#   'Dark',
#   'Shadow and Bone',
#   'The Good Doctor',
#   'Peaky Blinders'],
#  ['Hanna',
#   'Daredevil',
#   'Mr. Robot',
#   'Two and a half men',
#   'Lost in Space',
#   'How I met your mother'],
#  ['The Outsider', 'The Walking Dead', 'Archer', 'Lucifer'],
#  ['Breaking Bad', 'Sons of Anarchy', 'Ragnarok'],
#  [],
#  ['Sacred Games'],
#  ['The Blacklist', 'Stranger Things'],
#  ['Family Guy'],
#  ['Cobra Kai', 'The Walking Dead'],
#  ['The Witcher', 'How I met your mother', 'Lucifer'],
#  ['Outer Banks'],
#  ['The Stranger',
#   'Ozark',
#   'Atypical',
#   'Deception',
#   'Archer',
#   'Dark',
#   'Locke & Key'],
#  ['Doctor Who', 'Stranger Things'],
#  ['The Stranger',
#   'The Blacklist',
#   'Mr. Robot',
#   'The Wire',
#   'Brooklyn Nine Nine',
#   'Lucifer'],
#  ['The Wire', 'The Stranger', 'Ozark'],
#  ['Daredevil',
#   'The Blacklist',
#   'Mr. Robot',
#   'Atypical',
#   'The man in the high castle',
#   'The Walking Dead'],
#  ['Hanna',
#   'Ozark',
#   'Atypical',
#   'White Collar',
#   "Grey's Anatomy",
#   'Dr. House',
#   'Two and a half men',
#   'Hunters'],
#  ['Emily in Paris',
#   'The Walking Dead',
#   'Outer Banks',
#   'Mare of Easttown',
#   'Outlander'],
#  ['Cobra Kai', 'Lupin'],
#  ['Mr. Robot',
#   'Ozark',
#   'Dr. House',
#   'Vikings',
#   'Dexter',
#   'Stranger Things',
#   'Outer Banks',
#   'Dark',
#   'Locke & Key',
#   'Spartacus',
#   'Designated Survivor'],
#  ['Chernobyl', 'The Tick'],
#  ['Daredevil',
#   'Arrow',
#   'One Piece',
#   'Lost',
#   'Cobra Kai',
#   'Berlin Station',
#   'Atypical',
#   'Family Guy',
#   'Alice in Borderland',
#   'The Flash',
#   'Preacher',
#   'Doctor Who',
#   'Kingdom'],
#  ['Daredevil', 'Atypical', 'The Mentalist', 'Lucifer'],
#  ['Lost',
#   'Cobra Kai',
#   'Ozark',
#   'Berlin Station',
#   'Two and a half men',
#   'Punisher',
#   'American Gods',
#   'Designated Survivor',
#   'Westworld'],
#  ['The Wire', 'Ozark', 'The Flash', 'The Mentalist', 'Banshee'],
#  ['Constantine', 'Upload'],
#  ['Absentia'],
#  ['Stranger Things', 'Outer Banks', 'Absentia'],
#  ['The Outsider', 'How I met your mother'],
#  ['Person of Interest', 'Jack Ryan', 'The Witcher', 'Outer Banks'],
#  ['Arrow',
#   'Ozark',
#   'Family Guy',
#   'The Flash',
#   'Two and a half men',
#   'Outer Banks',
#   'Mare of Easttown',
#   'Shadow and Bone',
#   'The Night Manager'],
#  ['Demon Slayer'],
#  ['Absentia'],
#  ['Dark'],
#  ['Demon Slayer',
#   'Emily in Paris',
#   'Doctor Who',
#   'Banshee',
#   'Shadow and Bone',
#   'Chernobyl'],
#  ['Hanna', 'Atypical'],
#  ['Atypical', 'White Collar', 'Upload', 'Stranger Things', 'Dark'],
#  ['Cobra Kai',
#   'The Blacklist',
#   'Travellers',
#   'Emily in Paris',
#   'Outer Banks',
#   'Lucifer'],
#  ['Arrow',
#   'The Blacklist',
#   'Demon Slayer',
#   'Ozark',
#   'White Collar',
#   'Alice in Borderland',
#   'Dr. House',
#   'The Wire',
#   'The Mentalist'],
#  ['The Blacklist', 'Travellers', 'Punisher'],
#  ['Stranger Things', 'Mare of Easttown'],
#  ['Daredevil',
#   'Arrow',
#   'The Stranger',
#   'Ozark',
#   'Berlin Station',
#   'Family Guy',
#   'Preacher'],
#  ['Daredevil', 'Outer Banks', 'Outlander'],
#  ['Only Murders in the building'],
#  ['Cobra Kai'],
#  ['The Wire',
#   'One Piece',
#   'Ozark',
#   'Alice in Borderland',
#   'The Walking Dead',
#   'Vikings',
#   'Fringe',
#   'The White Lotus'],
#  ['Stranger Things'],
#  ['Daredevil',
#   'The Blacklist',
#   'Preacher',
#   'The Walking Dead',
#   'Stranger Things'],
#  ['Outer Banks'],
#  ['Dark'],
#  ['Rick And Morty',
#   'Berlin Station',
#   'Dr. House',
#   'Outer Banks',
#   'Locke & Key'],
#  ['The Outsider', 'Lucifer'],
#  ['Absentia'],
#  ['Cobra Kai', 'The Blacklist', 'Succession', 'Ozark', 'Lucifer'],
#  ['The Wire', 'Stranger Things', 'Outer Banks', 'Dark'],
#  ['Queen of the South',
#   'Lost',
#   'Rick And Morty',
#   'Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Constantine',
#   'Atypical',
#   'Doctor Who',
#   'Two and a half men',
#   'Vikings',
#   'The Witcher',
#   'Outer Banks',
#   'The Mentalist',
#   'How to get away with murder',
#   'Suits',
#   'Haven'],
#  ['Demon Slayer', 'Ozark', 'The Mentalist'],
#  ['The Walking Dead'],
#  ['Stranger Things', 'Chernobyl'],
#  ['Arrow',
#   'The Blacklist',
#   'Emily in Paris',
#   'The Wire',
#   'The Walking Dead',
#   'Spartacus',
#   'Designated Survivor',
#   'Brooklyn Nine Nine'],
#  ['Ozark',
#   'Preacher',
#   'Doctor Who',
#   'Two and a half men',
#   'Kingdom',
#   'Stranger Things',
#   'How I met your mother'],
#  ['White Collar', 'Two and a half men'],
#  ['Ozark',
#   'Atypical',
#   "Grey's Anatomy",
#   'Dr. House',
#   'Kingdom',
#   'Sense 8',
#   'The Witcher',
#   'Archer',
#   'Stranger Things',
#   'Absentia',
#   'Designated Survivor',
#   'Brooklyn Nine Nine',
#   'Perception',
#   'The Good Doctor',
#   'Chernobyl',
#   'Lucifer'],
#  ['Atypical', 'Breaking Bad', 'Lost in Space', 'Outer Banks'],
#  ['Outer Banks', 'Shadow and Bone', 'The Night Manager'],
#  ['Rick And Morty'],
#  ['Absentia'],
#  ['The Stranger', 'Into the night', 'Berlin Station', 'Jack Ryan', 'Preacher'],
#  ["Grey's Anatomy",
#   'Two and a half men',
#   'Kingdom',
#   'Homeland',
#   'How I met your mother',
#   'Lucifer'],
#  ['Absentia', 'How I met your mother'],
#  ['Outer Banks', 'Dark'],
#  ['Outer Banks', 'Designated Survivor'],
#  ['Absentia'],
#  ['Lost', 'Mare of Easttown', 'Locke & Key'],
#  ['The Wheel of Time', 'Westworld'],
#  ['The Nevers', 'Space Force', 'Outer Banks'],
#  ['Modern Family', 'Riverdale'],
#  ['Dark', 'Rome'],
#  ['Lupin', 'Stranger Things'],
#  ['One Piece',
#   'Family Guy',
#   'Two and a half men',
#   'Only Murders in the building',
#   'Outer Banks',
#   'Banshee',
#   'Shadow and Bone',
#   'The Night Manager'],
#  ['Rick And Morty', 'Atypical'],
#  ['Cobra Kai',
#   'Upload',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead'],
#  ['Hanna',
#   'Daredevil',
#   'White Collar',
#   'Doctor Who',
#   'Upload',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead',
#   'Sopranos',
#   'Archer'],
#  ['Daredevil', 'Two and a half men'],
#  ['Cobra Kai',
#   'Ozark',
#   'Berlin Station',
#   'Outer Banks',
#   'Dark',
#   'Absentia',
#   'Spartacus',
#   'Shadow and Bone',
#   'Ragnarok'],
#  ['One Piece', 'White Collar', 'Stranger Things', 'Outer Banks', 'Absentia'],
#  ['One Piece',
#   'The Blacklist',
#   'Modern Family',
#   'Two and a half men',
#   'How I met your mother'],
#  ['The Stranger',
#   'Cobra Kai',
#   'Succession',
#   'Ozark',
#   'Supergirl',
#   'Sense 8',
#   'Game of thrones',
#   'Vikings',
#   'Lost in Space'],
#  ['Deception', 'House of Cards', 'Stranger Things', 'Outer Banks'],
#  ['Cobra Kai',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Jack Ryan',
#   'Only Murders in the building',
#   'Shooter',
#   'Big Little Lies',
#   'How I met your mother'],
#  ['The Walking Dead', 'Outer Banks'],
#  ['The Blacklist',
#   'Jack Ryan',
#   'Two and a half men',
#   'Death Note',
#   'How I met your mother'],
#  ['One Piece',
#   'Lost',
#   'Cobra Kai',
#   'Rick And Morty',
#   'Succession',
#   'Family Guy',
#   'Locke & Key',
#   'Archer',
#   'Shadow and Bone'],
#  ['Archer', 'Goliath', 'Lucifer'],
#  ['Chernobyl'],
#  ['Daredevil',
#   'Arrow',
#   'Cobra Kai',
#   'Ozark',
#   'Berlin Station',
#   'The Flash',
#   'Invincible',
#   'Dr. House',
#   'Two and a half men',
#   'Kingdom',
#   '12 Monkeys',
#   'Outer Banks',
#   'The Night Manager'],
#  ['Jack Ryan',
#   'Family Guy',
#   'Sherlock',
#   'The Night Manager',
#   'The Expanse',
#   'Lucifer'],
#  ['The Blacklist', 'Ozark'],
#  ['Two and a half men', 'Stranger Things', 'Designated Survivor'],
#  ['Dark'],
#  ['Outer Banks'],
#  ['Two and a half men'],
#  ['Daredevil',
#   'The Stranger',
#   'Succession',
#   'Ozark',
#   'Better Call Saul',
#   'Berlin Station',
#   'Atypical',
#   'Emily in Paris',
#   'The Flash',
#   'Deception',
#   'Dr. House',
#   'The Wire',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Dark',
#   'Absentia',
#   'Friends',
#   'Spartacus',
#   'Shadow and Bone',
#   'The Night Manager',
#   'Bojack Horseman',
#   'The Wheel of Time'],
#  ['The Stranger',
#   'One Piece',
#   'The Blacklist',
#   'Family Guy',
#   'Only Murders in the building',
#   'Archer',
#   'Outer Banks',
#   'Lucifer'],
#  ['The Wire',
#   'Cobra Kai',
#   'Atypical',
#   'Prison Break',
#   'Deception',
#   'The Vampire Diaries',
#   '24',
#   'Black Clover'],
#  ['Hanna',
#   'Daredevil',
#   'Cobra Kai',
#   'Mr. Robot',
#   'Ozark',
#   'Atypical',
#   "Grey's Anatomy",
#   'Madmen',
#   'Two and a half men',
#   'Stranger Things'],
#  ['Demon Slayer', 'Outer Banks', 'Friends'],
#  ['The 100'],
#  ['Demon Slayer'],
#  ['Narcos'],
#  ['Cobra Kai', 'Person of Interest', 'Ozark', 'Jack Ryan'],
#  ['One Piece', 'Mr. Robot', 'Ozark', 'Dr. House', 'The Walking Dead'],
#  ['Rick And Morty',
#   'Atypical',
#   'Mare of Easttown',
#   'Absentia',
#   'The 100',
#   'Haven'],
#  ['The Outsider', 'Outer Banks', 'Mare of Easttown', 'The Newsroom'],
#  ['Ozark', 'Two and a half men'],
#  ['Jack Ryan', 'Atypical', 'Family Guy', 'Shooter', 'Outer Banks', 'Lucifer'],
#  ['Mr. Robot'],
#  ['Ozark',
#   'Atypical',
#   'The Outsider',
#   'Game of thrones',
#   '12 Monkeys',
#   'Punisher',
#   'Sherlock'],
#  ['One Piece',
#   'The Blacklist',
#   'Mr. Robot',
#   'Family Guy',
#   'Deception',
#   'Sense 8'],
#  ['Queen of the South',
#   'Berlin Station',
#   'Atypical',
#   'Deception',
#   'Dr. House',
#   'Two and a half men',
#   'Archer',
#   'Dark',
#   'You'],
#  ['One Piece', 'Emily in Paris'],
#  ['Hanna', 'Two and a half men'],
#  ['Mare of Easttown'],
#  ['Riverdale'],
#  ['Lost', 'White Collar', 'How to get away with murder'],
#  ['Rick And Morty',
#   'Family Guy',
#   'Only Murders in the building',
#   'Nine Perfect Strangers',
#   'The 100',
#   'The Tick',
#   'Lucifer'],
#  ['Archer', 'Shadow and Bone', 'Lucifer'],
#  ['Absentia'],
#  ['Demon Slayer', '12 Monkeys'],
#  ['Gotham'],
#  ['One Piece', 'Two and a half men'],
#  ['Hanna', 'The Stranger', 'Travellers', '12 Monkeys', 'Banshee'],
#  ['Inhumans', 'Atypical'],
#  ['Constantine', 'The Mentalist', 'Banshee', 'Spartacus'],
#  ['Stranger Things', 'Outer Banks'],
#  ['Jack Ryan', 'Atypical', 'Madmen', 'Vikings', 'Shooter'],
#  ['Kingdom', 'Shadow and Bone', 'Startup', 'How I met your mother'],
#  ['Ozark', 'How to get away with murder'],
#  ['One Piece'],
#  ['The Wire'],
#  ['Squid Game', 'Shadow and Bone'],
#  ['Daredevil',
#   'The Wire',
#   'One Piece',
#   'Queen of the South',
#   'Mr. Robot',
#   'Ozark',
#   'White Collar',
#   'Game of thrones',
#   'Perception',
#   'Lucifer'],
#  ['Elementary', 'Succession', 'How to get away with murder'],
#  ['Hanna',
#   'The Wire',
#   'The Walking Dead',
#   'Nine Perfect Strangers',
#   'Outer Banks',
#   'Lucifer'],
#  [],
#  ['Hanna',
#   'Two and a half men',
#   'The Walking Dead',
#   'Squid Game',
#   'Brooklyn Nine Nine'],
#  ['Hanna',
#   'One Piece',
#   'Cobra Kai',
#   'Family Guy',
#   'Two and a half men',
#   'Only Murders in the building',
#   'Vikings',
#   'The Big Bang Theory',
#   'Stranger Things',
#   'Dark'],
#  ['Travellers'],
#  ['Spartacus'],
#  ['Perception', 'The Good Doctor', 'Lucifer'],
#  ['Daredevil', "Grey's Anatomy", 'Dark'],
#  ['Two and a half men', 'Sherlock', 'How to get away with murder'],
#  ['Hanna',
#   'Demon Slayer',
#   'Ozark',
#   'Atypical',
#   'Madmen',
#   'Two and a half men',
#   'The Wire',
#   'The Walking Dead',
#   'Archer',
#   'Outer Banks',
#   'Spartacus',
#   'Big Little Lies'],
#  ['Mindhunter'],
#  ['True Detective', 'Two and a half men'],
#  ['Atypical', 'Emily in Paris', 'Archer'],
#  ['12 Monkeys'],
#  ['Queen of the South',
#   'Two and a half men',
#   'Nine Perfect Strangers',
#   'Outer Banks'],
#  ['The Outsider', 'Outer Banks', 'Designated Survivor'],
#  ['Inhumans', 'Two and a half men', 'Mare of Easttown', 'Shadow and Bone'],
#  ['The Stranger', 'The Newsroom'],
#  ['Dark'],
#  ['Hanna', '12 Monkeys', 'Stranger Things', 'Outer Banks', 'Perception'],
#  ['One Piece'],
#  ['The Blacklist', 'Atypical', 'Preacher'],
#  ['Peaky Blinders'],
#  ['Cobra Kai', 'Constantine', 'Ragnarok'],
#  ['Two and a half men',
#   'Archer',
#   'Dexter',
#   'How to get away with murder',
#   'Designated Survivor'],
#  ['Stranger Things'],
#  ['Daredevil',
#   'Demon Slayer',
#   'The Wire',
#   'The Innocent',
#   'House of Cards',
#   'Only Murders in the building',
#   'Vikings',
#   'Stranger Things',
#   'Outer Banks',
#   'Dark'],
#  ['One Piece', 'Cobra Kai'],
#  ['Daredevil',
#   'Cobra Kai',
#   'Rick And Morty',
#   'Ozark',
#   'Berlin Station',
# ...
#  ['Rick And Morty',
#   'Ozark',
#   'Atypical',
#   '12 Monkeys',
#   'Sopranos',
#   'The Mentalist',
#   'Perception'],
#  ['The Stranger', 'The Outsider'],
#  ['One Piece', 'Atypical', 'Archer'],
#  ['Two and a half men', 'Lupin'],
#  ['Cobra Kai', 'Ozark'],
#  ['One Piece',
#   'Ozark',
#   'Family Guy',
#   'Two and a half men',
#   'Kingdom',
#   'The Walking Dead',
#   'Vikings',
#   'The Tick'],
#  ['Mr. Robot', 'Ozark', 'Deception'],
#  ['Demon Slayer', 'Hunters', 'Chernobyl'],
#  ['Absentia', 'How I met your mother'],
#  ['Ozark', 'Atypical', 'Family Guy', 'Spartacus'],
#  ['Two and a half men', 'The Walking Dead'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Ozark',
#   'Constantine',
#   'Atypical',
#   'White Collar',
#   'Punisher',
#   'Shooter',
#   'Spartacus'],
#  ['Hanna',
#   'The Blacklist',
#   'Two and a half men',
#   'Stranger Things',
#   'Chernobyl'],
#  ['Mare of Easttown', 'Chernobyl'],
#  ['Gotham'],
#  ['Lucifer'],
#  ["Grey's Anatomy",
#   'Two and a half men',
#   'Sherlock',
#   'Chernobyl',
#   'Peaky Blinders'],
#  ['Outer Banks'],
#  ['Demon Slayer',
#   'Travellers',
#   'Preacher',
#   'Dr. House',
#   'Two and a half men',
#   'Kingdom'],
#  ['Daredevil'],
#  ['Doctor Who', 'Outer Banks', 'Lucifer'],
#  ['Family Guy', 'Deception', 'Doctor Who'],
#  ['Emily in Paris'],
#  ['Daredevil',
#   'Constantine',
#   'Alice in Borderland',
#   'Kingdom',
#   'Perception',
#   'The White Lotus',
#   'Peaky Blinders',
#   'Lucifer'],
#  ['One Piece', 'Deception', 'The Walking Dead', 'Mare of Easttown'],
#  ['Mr. Robot', 'Ozark', 'Atypical'],
#  ['Constantine', 'The Mentalist', 'Loki', 'Brooklyn Nine Nine'],
#  ['Kingdom', 'The Walking Dead'],
#  ['Demon Slayer', 'The Alienist'],
#  ['Ozark',
#   'Berlin Station',
#   'Dr. House',
#   'Spartacus',
#   'The Night Manager',
#   'Ragnarok',
#   'Perception'],
#  ['Hanna',
#   'One Piece',
#   'Queen of the South',
#   'The Blacklist',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Two and a half men',
#   'The Walking Dead',
#   'Archer',
#   'The Mentalist',
#   'Shadow and Bone',
#   'Big Little Lies',
#   'How I met your mother'],
#  ['Dark', 'Loki'],
#  ['Two and a half men', 'Lucifer'],
#  ['Outer Banks'],
#  ['Demon Slayer', 'Outer Banks', 'Haven', 'Designated Survivor'],
#  ['Outer Banks', 'Loki', 'The Expanse'],
#  ['One Piece'],
#  ['Deception'],
#  ['Riverdale'],
#  ['Daredevil',
#   'Queen of the South',
#   'Mr. Robot',
#   'Ozark',
#   'The Wire',
#   'The Walking Dead',
#   'Outer Banks',
#   'Lucifer'],
#  ['Only Murders in the building', 'The Mentalist'],
#  ['The Stranger'],
#  ['The Wire', 'Absentia'],
#  ['Kingdom', 'Orphan Black', 'The Umbrella Academy'],
#  ['Two and a half men', 'Kingdom'],
#  ['The Blacklist',
#   'Ozark',
#   'Two and a half men',
#   'The Wire',
#   'Dark',
#   'Peaky Blinders'],
#  ['Demon Slayer',
#   'Rick And Morty',
#   'Ozark',
#   'Atypical',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead',
#   '12 Monkeys'],
#  ['One Piece',
#   'The Blacklist',
#   'Demon Slayer',
#   'Family Guy',
#   'Perception',
#   'The Good Doctor',
#   'Chernobyl',
#   'Lucifer'],
#  ['Family Guy'],
#  ['One Piece', 'Constantine'],
#  ['Absentia', 'Spartacus', 'Shadow and Bone'],
#  ['Mr. Robot',
#   'Better Call Saul',
#   'Berlin Station',
#   'Family Guy',
#   'Two and a half men'],
#  ['Designated Survivor'],
#  ['Demon Slayer',
#   'Travellers',
#   'White Collar',
#   'The Outsider',
#   'Two and a half men',
#   'Westworld',
#   'How I met your mother'],
#  ['Two and a half men', 'The Mentalist'],
#  ['Travellers', 'Brooklyn Nine Nine', 'Chernobyl'],
#  ['Succession', 'Two and a half men'],
#  ['The Night Manager'],
#  ['Hanna', 'Two and a half men', 'Absentia'],
#  ['Dark'],
#  ['The Blacklist', 'Constantine', 'Atypical', 'Homeland', 'Big Little Lies'],
#  ['Perception', 'Grimm', 'Big Little Lies'],
#  ['Demon Slayer'],
#  ['Ozark',
#   'Better Call Saul',
#   'Constantine',
#   'Deception',
#   'Dr. House',
#   'Game of thrones',
#   'The Innocent',
#   'Vikings'],
#  ['Two and a half men', 'Rome'],
#  ['The Stranger',
#   'One Piece',
#   'The Boys',
#   'Ozark',
#   'Dr. House',
#   'Two and a half men',
#   'The Walking Dead',
#   'Outer Banks',
#   'Brooklyn Nine Nine'],
#  ['Preacher', 'Designated Survivor'],
#  ['Stranger Things', 'The Newsroom', 'Brooklyn Nine Nine'],
#  ['Loki'],
#  ['Ozark', 'Two and a half men'],
#  ['Hanna',
#   'Lost',
#   'Archer',
#   'Stranger Things',
#   'Dark',
#   'Spartacus',
#   'Shadow and Bone'],
#  ['The Blacklist', 'Ozark', 'Archer'],
#  ['The Wire',
#   'Queen of the South',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Atypical',
#   'Deception',
#   'Doctor Who',
#   'Archer',
#   'Banshee',
#   'Lucifer'],
#  ['Hanna'],
#  ['Rome'],
#  ['House of Cards',
#   'Sopranos',
#   'Sons of Anarchy',
#   'Nine Perfect Strangers',
#   'Outer Banks',
#   'How I met your mother'],
#  ['Atypical'],
#  ['Cobra Kai',
#   'Mr. Robot',
#   'Better Call Saul',
#   'Atypical',
#   'The Witcher',
#   'Stranger Things',
#   'Shadow and Bone',
#   'Chernobyl'],
#  ['Into the night',
#   'The Blacklist',
#   'Mr. Robot',
#   'Ozark',
#   'Jack Ryan',
#   'Family Guy',
#   'The Newsroom'],
#  ['Hanna',
#   'One Piece',
#   'Queen of the South',
#   'The Blacklist',
#   'Ozark',
#   'Atypical',
#   'Two and a half men',
#   'Lupin',
#   'Lost in Space',
#   'Outer Banks',
#   'How I met your mother'],
#  ['The Blacklist',
#   'Mr. Robot',
#   'Deception',
#   'The Outsider',
#   'Stranger Things',
#   'The IT Crowd'],
#  ['Only Murders in the building'],
#  ['Riverdale'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Two and a half men',
#   'The Walking Dead',
#   'The Mentalist',
#   'How to get away with murder',
#   'Perception',
#   'Banshee'],
#  ['Kingdom'],
#  ['Cobra Kai', 'Berlin Station', 'White Collar', '12 Monkeys', 'Dark'],
#  ['Daredevil',
#   'Arrow',
#   'Queen of the South',
#   'Cobra Kai',
#   'Rick And Morty',
#   'Atypical',
#   'Madmen',
#   'Two and a half men',
#   'The Witcher',
#   'Shadow and Bone',
#   'Brooklyn Nine Nine'],
#  ['Emily in Paris', 'Doctor Who', 'Brooklyn Nine Nine', 'The Night Manager'],
#  ['Lost', 'Succession', 'Two and a half men', 'House of Cards'],
#  ['The Blacklist',
#   'The Flash',
#   'Two and a half men',
#   'The Witcher',
#   'Stranger Things',
#   'Hunters'],
#  ['Designated Survivor'],
#  ['Demon Slayer',
#   'Mr. Robot',
#   'Atypical',
#   'The Wire',
#   'Outer Banks',
#   'Shadow and Bone',
#   'Big Little Lies'],
#  ['The Mentalist', 'How to get away with murder'],
#  ['Atypical', 'The Mentalist', 'How I met your mother'],
#  [],
#  ['The Stranger'],
#  ['Ozark', 'Travellers', 'White Collar', 'Kingdom', 'Stranger Things'],
#  ['Mr. Robot',
#   'Person of Interest',
#   'Atypical',
#   'Family Guy',
#   'White Collar',
#   'Deception',
#   'Banshee'],
#  ['The Wire',
#   'The Stranger',
#   'One Piece',
#   'Mr. Robot',
#   'Two and a half men',
#   'Perception'],
#  ['Hanna',
#   'White Collar',
#   'The Flash',
#   'Madmen',
#   'Kingdom',
#   'The Walking Dead',
#   'Stranger Things',
#   'Ragnarok',
#   'Lucifer'],
#  ['Absentia', 'How I met your mother'],
#  ['Arrow', 'Berlin Station', 'Prison Break'],
#  ['Hanna',
#   'Queen of the South',
#   'The Blacklist',
#   'Mr. Robot',
#   'Better Call Saul',
#   'Deception'],
#  ["Grey's Anatomy", 'Two and a half men', 'Kingdom'],
#  ['Archer'],
#  ['Mr. Robot', 'Atypical', 'Emily in Paris'],
#  ['Daredevil', 'Mr. Robot', 'Dr. House', 'Hunters'],
#  ['Ozark', 'Two and a half men', 'Black Clover'],
#  ['The Outsider', 'Sherlock'],
#  ['Dark'],
#  ['Cobra Kai',
#   'Dr. House',
#   'Altered Carbon',
#   'Nine Perfect Strangers',
#   'Mare of Easttown',
#   'Perception'],
#  ['Spartacus', 'Designated Survivor'],
#  ['The Blacklist',
#   'Ozark',
#   'Jack Ryan',
#   'Upload',
#   'Two and a half men',
#   '12 Monkeys',
#   'The Nevers'],
#  ['Designated Survivor'],
#  ['Queen of the South',
#   'Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Constantine',
#   'Preacher',
#   'Two and a half men',
#   'Shadow and Bone'],
#  ['Ozark', 'Jack Ryan'],
#  ['Mr. Robot'],
#  ['Outer Banks'],
#  ['Dark'],
#  ['Deception', 'Stranger Things'],
#  ['Absentia', 'How I met your mother'],
#  ['One Piece'],
#  ['Hanna',
#   'Breaking Bad',
#   'The Outsider',
#   'Black Clover',
#   'Big Little Lies',
#   'The IT Crowd'],
#  ['Dark'],
#  ['Cobra Kai', 'The Blacklist', 'Only Murders in the building'],
#  ['Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Jack Ryan',
#   'Atypical',
#   'Supergirl',
#   'Spartacus'],
#  ['Lucifer'],
#  ['Perception'],
#  ['Demon Slayer', 'Two and a half men', 'Vikings', 'Punisher'],
#  ['Daredevil', 'Ozark', 'Two and a half men'],
#  [],
#  ['Cobra Kai', 'The Blacklist', 'Ozark', 'Jack Ryan', 'Two and a half men'],
#  ['Hanna',
#   'Atypical',
#   'Billions',
#   'Deception',
#   'Two and a half men',
#   'Perception'],
#  ['Travellers', 'Atypical'],
#  ['Hanna',
#   'The Wire',
#   'Lost',
#   'Rick And Morty',
#   'Berlin Station',
#   'House of Cards',
#   'Watchmen',
#   'Archer',
#   'The Mentalist',
#   'Chernobyl'],
#  ['Daredevil',
#   'The Blacklist',
#   'Ozark',
#   'Berlin Station',
#   'Alice in Borderland',
#   'Dr. House',
#   'Two and a half men',
#   'Kingdom',
#   'Chernobyl'],
#  ['One Piece', 'Breaking Bad', 'Dark'],
#  ['Arrow', 'The Wire', 'Dark'],
#  ['Berlin Station'],
#  ['Arrow',
#   'The Blacklist',
#   'Berlin Station',
#   'Preacher',
#   'Dr. House',
#   'The Wire',
#   'The Walking Dead',
#   'Homeland',
#   'The Mentalist',
#   'Shadow and Bone',
#   'Lucifer'],
#  ['Mr. Robot', 'Berlin Station', '12 Monkeys'],
#  ['Outer Banks'],
#  ['Absentia'],
#  ['The Stranger', 'Deception', 'Kingdom', 'Vikings', 'Nine Perfect Strangers'],
#  ['Emily in Paris', 'Banshee'],
#  ['Lost',
#   'Cobra Kai',
#   'Berlin Station',
#   'Deception',
#   'House of Cards',
#   'Mindhunter',
#   'Archer'],
#  ['Arrow',
#   'Succession',
#   'Ozark',
#   'Family Guy',
#   "Grey's Anatomy",
#   'Alice in Borderland',
#   'Kingdom',
#   'Shooter',
#   'Mindhunter',
#   'How to get away with murder',
#   'Designated Survivor',
#   'The Tick'],
#  ['Queen of the South'],
#  ['Rome', 'Locke & Key'],
#  ['Dr. House',
#   'Two and a half men',
#   'Kingdom',
#   'Designated Survivor',
#   'Lucifer'],
#  ['Family Guy',
#   'Two and a half men',
#   'Outer Banks',
#   'Spartacus',
#   'The Night Manager',
#   'The IT Crowd'],
#  ['One Piece'],
#  ['Hanna', 'Two and a half men', 'The IT Crowd', 'Lucifer'],
#  ['Atypical', 'Vikings', 'Lucifer'],
#  ['Daredevil',
#   'Queen of the South',
#   'The Blacklist',
#   'Ozark',
#   'Berlin Station',
#   'Atypical',
#   'White Collar',
#   'Prison Break',
#   'Alice in Borderland',
#   'The Innocent',
#   'The Big Bang Theory',
#   'Mindhunter',
#   'How I met your mother'],
#  ['Cobra Kai', 'Demon Slayer', 'Ozark', 'Deception', 'Stranger Things'],
#  ['Jack Ryan', 'Outer Banks'],
#  ['The Walking Dead', 'Outer Banks', 'Lucifer'],
#  ['Ozark'],
#  ['One Piece',
#   'Queen of the South',
#   'Cobra Kai',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Succession',
#   'Ozark',
#   'Berlin Station',
#   'The Outsider',
#   'Stranger Things',
#   'Spartacus',
#   'How I met your mother',
#   'Lucifer'],
#  ['Doctor Who', 'The Walking Dead', 'The Mentalist', 'Spartacus'],
#  ['The Wire',
#   'Mr. Robot',
#   'Berlin Station',
#   'Breaking Bad',
#   'Dr. House',
#   'Stranger Things',
#   'Outer Banks',
#   'Big Little Lies'],
#  ['Archer'],
#  ['The Outsider'],
#  ['Archer'],
#  ['Demon Slayer', 'Berlin Station', 'Jack Ryan', 'Shadow and Bone'],
#  ['Better Call Saul', 'Emily in Paris', 'Two and a half men', 'Chernobyl'],
#  ['The Blacklist', 'Mr. Robot', 'Family Guy', 'Dr. House'],
#  ['Family Guy', 'Chernobyl'],
#  ['The Witcher', 'Shadow and Bone'],
#  ['The Stranger', 'Ozark', 'Two and a half men', 'Lucifer'],
#  ['Daredevil',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Family Guy',
#   'Breaking Bad',
#   'Vikings',
#   'Punisher',
#   'The Nevers',
#   'Archer',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'How to get away with murder',
#   'Banshee',
#   'The Night Manager',
#   'Chernobyl'],
#  ['Elementary', 'Rome', 'Lucifer'],
#  ['The Wire',
#   'Ozark',
#   'Emily in Paris',
#   'Two and a half men',
#   '12 Monkeys',
#   'Shadow and Bone',
#   'Chernobyl',
#   'How I met your mother'],
#  ['Hanna',
#   'The Wire',
#   'One Piece',
#   'Queen of the South',
#   'Rick And Morty',
#   'Ozark',
#   'Dr. House',
#   'Fringe',
#   'Archer',
#   'You'],
#  ['The Walking Dead', '12 Monkeys', 'Archer'],
#  ['The Blacklist', 'Travellers', 'Kingdom', 'Stranger Things'],
#  ['Travellers', 'Alice in Borderland'],
#  ['Outer Banks', 'The Mentalist'],
#  ['Outer Banks'],
#  ['The Walking Dead', 'Lupin', 'Vikings'],
#  [],
#  ['Designated Survivor'],
#  ['Mr. Robot', 'Kingdom', 'Sopranos', 'The Witcher', 'Absentia'],
#  ['Outer Banks',
#   'Absentia',
#   'The Newsroom',
#   'Big Little Lies',
#   'Chernobyl',
#   'How I met your mother'],
#  ['Daredevil',
#   'The Wire',
#   'The Stranger',
#   'Lost',
#   'The Blacklist',
#   'Person of Interest',
#   'Ozark',
#   'The Outsider',
#   'The Wire',
#   'Outer Banks',
#   'Designated Survivor',
#   'Hunters',
#   'Schitts Creek'],
#  ['The Stranger', 'Cobra Kai', 'Two and a half men', 'Stranger Things'],
#  ['Daredevil', 'Two and a half men', 'Designated Survivor'],
#  ['Gotham'],
#  ['Dark'],
#  ['One Piece', 'How I met your mother'],
#  ['Demon Slayer',
#   'Emily in Paris',
#   'Deception',
#   'Doctor Who',
#   'Stranger Things',
#   'Outer Banks',
#   'How to get away with murder'],
#  ['Hanna',
#   'Arrow',
#   'Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Person of Interest',
#   'Ozark',
#   'Atypical',
#   'Family Guy',
#   'Breaking Bad',
#   'Dr. House',
#   'The Wire',
#   'Archer',
#   'Dark'],
#  ['Absentia'],
#  ['Outer Banks'],
#  ['Cobra Kai', 'Lupin', 'How I met your mother'],
#  ['Ozark', 'Only Murders in the building'],
#  ['The Blacklist', '12 Monkeys'],
#  ['Daredevil',
#   "Grey's Anatomy",
#   'Two and a half men',
#   'Stranger Things',
#   'Designated Survivor'],
#  ['Outer Banks', 'The Mentalist'],
#  ['Daredevil',
#   'Two and a half men',
#   'Shadow and Bone',
#   'The Night Manager',
#   'Lucifer'],
#  ['Into the night',
#   'Ozark',
#   'Family Guy',
#   'Shooter',
#   'Dexter',
#   'Stranger Things',
#   'Locke & Key'],
#  ['Daredevil',
#   'The Wire',
#   'Into the night',
#   'Cobra Kai',
#   'The Blacklist',
#   'Demon Slayer',
#   'Mr. Robot',
#   'Succession',
#   'Person of Interest',
#   'Ozark',
#   'Jack Ryan',
#   'Atypical',
#   'Family Guy',
#   "Grey's Anatomy",
#   'Preacher',
#   'Deception',
#   'Kingdom',
#   'The Walking Dead',
#   'Lupin',
#   '12 Monkeys'],
#  ['The Outsider'],
#  ['White Collar'],
#  ['Absentia'],
#  ['Stranger Things', 'Outer Banks', 'Dark'],
#  ['12 Monkeys',
#   'Punisher',
#   'Stranger Things',
#   'Dark',
#   'Spartacus',
#   'Chernobyl'],
#  ['Dr. House'],
#  ['Queen of the South', 'Vikings', 'Absentia'],
#  ['Jack Ryan',
#   'Constantine',
#   'Mare of Easttown',
#   'Outlander',
#   'The IT Crowd',
#   'Startup',
#   'How I met your mother'],
#  ['The Walking Dead'],
#  ['Absentia'],
#  ['Designated Survivor'],
#  ['Stranger Things', 'How I met your mother'],
#  ['Big Little Lies'],
#  ['Absentia'],
#  ['Absentia'],
#  ['The Wire',
#   'Elementary',
#   'Ozark',
#   'Two and a half men',
#   'Kingdom',
#   'Outer Banks',
#   'Rome'],
#  ['Demon Slayer'],
#  ['Rick And Morty',
#   'Mr. Robot',
#   'Atypical',
#   'Family Guy',
#   'Inside Job',
#   'Rome',
#   'The White Lotus'],
#  ['Friends'],
#  ['Daredevil',
#   'Mr. Robot',
#   'Ozark',
#   'Berlin Station',
#   'Dr. House',
#   'Two and a half men'],
#  ['Two and a half men',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia',
#   'Rome',
#   'Banshee',
#   'Lucifer'],
#  [],
#  ['Rick And Morty',
#   'Mr. Robot',
#   'The Flash',
#   'Madmen',
#   'Stranger Things',
#   'Outer Banks',
#   'Dark',
#   'Chernobyl'],
#  ['The Blacklist',
#   'Demon Slayer',
#   'Jack Ryan',
#   'Atypical',
#   'Kingdom',
#   'The Walking Dead',
#   'Sacred Games'],
#  ['Constantine',
#   'Deception',
#   'Two and a half men',
#   '12 Monkeys',
#   'Stranger Things',
#   'Locke & Key',
#   'How I met your mother'],
#  ['Hanna', 'Atypical', '12 Monkeys', 'Stranger Things'],
#  ['Hanna',
#   'Ozark',
#   'Atypical',
#   'Two and a half men',
#   'The Walking Dead',
#   '12 Monkeys',
#   'Vikings',
#   'Spartacus',
#   'Shadow and Bone',
#   'Outlander'],
#  ['One Piece', 'How I met your mother'],
#  ['Absentia'],
#  ['Demon Slayer',
#   'Stranger Things',
#   'Outer Banks',
#   'The Mentalist',
#   'Absentia',
#   'How I met your mother'],
#  ['Demon Slayer',
#   'Ozark',
#   'Atypical',
#   'Doctor Who',
#   'The Walking Dead',
#   'Spartacus',
#   'Brooklyn Nine Nine'],
#  ['Atypical', 'Brooklyn Nine Nine'],
#  ['Daredevil', 'Two and a half men', 'Riverdale'],
#  ['Two and a half men', '12 Monkeys'],
#  ['The Outsider'],
#  ['Succession',
#   'Berlin Station',
#   'Sense 8',
#   'Only Murders in the building',
#   'Chernobyl',
#   'How I met your mother'],
#  ['Outer Banks'],
#  ['Travellers', 'Preacher', 'Archer'],
#  ['Hanna', '12 Monkeys', 'The Wheel of Time'],
#  ['Outer Banks'],
#  ...]

# %% [markdown]
# ### Recreating the dataframe :

# %%
shows = pd.DataFrame({"Watched":TVshows})
pd.options.display.max_colwidth=1000

# %%
shows
# Out:
#                                                                                                                                                   Watched
# 0                                                                                                                [Cobra Kai, Lupin, 12 Monkeys, Sherlock]
# 1     [Lost, Jack Ryan, The Flash, Game of thrones, House of Cards, 12 Monkeys, Vikings, Fringe, The Mentalist, The Alienist, Big Little Lies, Chernobyl]
# 2                                                                                                                  [Dr. House, Kingdom, The Walking Dead]
# 3                                                                                                       [Ozark, Constantine, Preacher, Vikings, The Tick]
# 4                                                                                                                                                [Naruto]
# ...                                                                                                                                                   ...
# 9685                                                                   [One Piece, The Blacklist, Two and a half men, Lupin, Dark, How I met your mother]
# 9686                                                                  [One Piece, Mr. Robot, Succession, Ozark, 12 Monkeys, Vikings, The Vampire Diaries]
# 9687                                                                                                                         [Daredevil, Atypical, Heros]
# 9688                                                                                                               [Absentia, The Newsroom, The Alienist]
# 9689                                                                                                                                           [Atypical]
#
# [9690 rows x 1 columns]

# %%
## In this section we selected the lists that contain at leasy 19 elemnts so we can get proper results : 
shows = shows[shows['Watched'].apply(lambda x: len(x) >= 19)]
shows
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                    Watched
# 85                                                                                                                                                          [Daredevil, The Stranger, Demon Slayer, The Boys, Rick And Morty, Mr. Robot, Succession, Ozark, Berlin Station, Family Guy, The Outsider, Two and a half men, 12 Monkeys, Sopranos, Sherlock, Stranger Things, Absentia, You, Big Little Lies]
# 361                                                                                                                            [Hanna, Into the night, The Blacklist, The Boys, Mr. Robot, Ozark, Deception, Doctor Who, The man in the high castle, The Walking Dead, Lost in Space, Mindhunter, Outer Banks, Mare of Easttown, How to get away with murder, Haven, Shadow and Bone, Perception, Startup]
# 601                                                                                           [Daredevil, The Stranger, Succession, Ozark, Better Call Saul, Berlin Station, Atypical, Emily in Paris, The Flash, Deception, Dr. House, The Wire, Stranger Things, Outer Banks, The Mentalist, Dark, Absentia, Friends, Spartacus, Shadow and Bone, The Night Manager, Bojack Horseman, The Wheel of Time]
# 733                                                                                                            [Daredevil, The Blacklist, Demon Slayer, Grey's Anatomy, Breaking Bad, The Wire, The Walking Dead, Lupin, Only Murders in the building, Sopranos, Sons of Anarchy, Outer Banks, Mare of Easttown, Banshee, Spartacus, Shadow and Bone, Designated Survivor, Perception, Chernobyl, Startup]
# 959                                                                                                                                                    [Daredevil, The Wire, Into the night, Cobra Kai, The Blacklist, Demon Slayer, Mr. Robot, Succession, Person of Interest, Ozark, Jack Ryan, Atypical, Family Guy, Grey's Anatomy, Preacher, Deception, Kingdom, The Walking Dead, Lupin, 12 Monkeys]
# 1189                                                                                                                          [Inhumans, Arrow, Demon Slayer, Mr. Robot, Ozark, Jack Ryan, Constantine, Travellers, Atypical, True Detective, The Wire, The Walking Dead, Locke & Key, Vikings, The Umbrella Academy, Archer, Outer Banks, The Mentalist, How to get away with murder, Banshee, Chernobyl]
# 1229  [The Wire, Into the night, The Blacklist, Mr. Robot, Succession, Ozark, Berlin Station, Atypical, Family Guy, Alice in Borderland, The Flash, Doctor Who, Upload, Dr. House, The Wire, The Innocent, Locke & Key, Only Murders in the building, 12 Monkeys, Sopranos, Punisher, Nine Perfect Strangers, Stranger Things, The Mentalist, The Queen's Gambit, Banshee, Shadow and Bone, American Gods]
# 1255                                                                                                                                         [The Blacklist, Ozark, Atypical, Dr. House, Two and a half men, The Walking Dead, Lupin, Mirzapur, Only Murders in the building, 12 Monkeys, Death Note, Archer, Stranger Things, Outer Banks, Squid Game, Spartacus, Outlander, The Night Manager, Ragnarok]
# 1382                                   [Daredevil, Demon Slayer, Mr. Robot, Succession, Berlin Station, Constantine, Grey's Anatomy, Preacher, Dr Stone, Dr. House, The Innocent, House of Cards, X-Files, Only Murders in the building, Sopranos, Sons of Anarchy, Shooter, Lost in Space, Black Clover, Dexter, Homeland, Mare of Easttown, Dark, Rome, Shadow and Bone, Schitts Creek, Big Little Lies]
# 1812                                                                                                                                             [Hanna, The Stranger, Mr. Robot, Ozark, Constantine, Travellers, Atypical, Family Guy, Alice in Borderland, The Flash, The Walking Dead, Lupin, Game of thrones, House of Cards, Shooter, Designated Survivor, Westworld, How I met your mother, Lucifer]
# 1906                                                                                                                 [Hanna, The Stranger, One Piece, Queen of the South, Lost, The Blacklist, Rick And Morty, The Walking Dead, Sense 8, Only Murders in the building, 12 Monkeys, Vikings, Narcos, Sopranos, The Big Bang Theory, Sacred Games, The Nevers, Stranger Things, Dark, Dark, Peaky Blinders]
# 2931                                                                                     [Hanna, The Stranger, Queen of the South, Cobra Kai, The Blacklist, Mr. Robot, Ozark, Jack Ryan, Constantine, Family Guy, Grey's Anatomy, Preacher, Deception, Doctor Who, The man in the high castle, Dr. House, The Wire, Lupin, Only Murders in the building, Dexter, Outer Banks, The Mentalist, The Expanse]
# 3183                                                                                                                         [Queen of the South, Cobra Kai, The Blacklist, Demon Slayer, Rick And Morty, Mr. Robot, Ozark, Constantine, Alice in Borderland, Two and a half men, Game of thrones, Vikings, Lost in Space, Homeland, Outer Banks, Dark, Shadow and Bone, Chernobyl, How I met your mother]
# 3376                                                                                                                                      [Hanna, The Stranger, One Piece, The Blacklist, Demon Slayer, Atypical, Family Guy, Deception, Lupin, Mirzapur, Game of thrones, X-Files, 12 Monkeys, Lost in Space, Stranger Things, Outer Banks, Spartacus, Shadow and Bone, Outlander, Perception, Chernobyl]
# 3479                                             [Hanna, Daredevil, Inhumans, Queen of the South, The Blacklist, Demon Slayer, Mr. Robot, Succession, Berlin Station, Atypical, Family Guy, Alice in Borderland, Preacher, Doctor Who, The man in the high castle, Dr. House, Two and a half men, Sense 8, The Innocent, Locke & Key, 12 Monkeys, The Nevers, Archer, Banshee, Spartacus, Big Little Lies]
# 4029                                                                                                         [The Stranger, The Blacklist, Demon Slayer, Mr. Robot, Ozark, Berlin Station, Atypical, Family Guy, The Flash, Deception, Supergirl, Dr. House, The Wire, Locke & Key, Inside Job, Nine Perfect Strangers, Stranger Things, The Mentalist, Banshee, The Good Doctor, Chernobyl, The IT Crowd]
# 4040                                                                                                                                        [Lost, The Blacklist, Ozark, Berlin Station, Jack Ryan, Constantine, Atypical, Family Guy, White Collar, Dr. House, The Walking Dead, Game of thrones, 12 Monkeys, Sacred Games, Black Clover, The Witcher, Stranger Things, Dark, Big Little Lies, Chernobyl]
# 4211                                                                                                                                          [Arrow, The Blacklist, The Boys, Succession, Ozark, Atypical, Family Guy, Grey's Anatomy, Alice in Borderland, Deception, The Wire, The Walking Dead, Lupin, Only Murders in the building, The Witcher, Stranger Things, The Mentalist, Perception, Startup]
# 4711                                                                                                                                      [Hanna, Arrow, The Blacklist, Demon Slayer, Mr. Robot, Ozark, Berlin Station, Jack Ryan, Atypical, Family Guy, Grey's Anatomy, Alice in Borderland, Preacher, Doctor Who, Supergirl, Dr. House, The Wire, Vikings, Sacred Games, The Mentalist, Dark, Spartacus]
# 4795                                                                                                                         [Daredevil, Arrow, One Piece, Queen of the South, Lost, The Blacklist, Demon Slayer, Rick And Morty, Ozark, Jack Ryan, Constantine, Atypical, Alice in Borderland, Madmen, Lupin, Shooter, Stranger Things, Mare of Easttown, Homeland, Spartacus, Shadow and Bone, Ragnarok]
# 4912                                                                                                                                    [Hanna, Into the night, Cobra Kai, Jack Ryan, The man in the high castle, Two and a half men, The Wire, The Walking Dead, Lupin, Lost in Space, Mindhunter, Stranger Things, Outer Banks, The Mentalist, Dark, Rome, Sherlock, Shadow and Bone, The Night Manager]
# 4945                                                                                                     [Hanna, The Stranger, Queen of the South, Lost, The Blacklist, Ozark, Berlin Station, Jack Ryan, Travellers, Atypical, Family Guy, White Collar, Deception, The Walking Dead, Game of thrones, 12 Monkeys, Black Clover, Archer, The Mentalist, How to get away with murder, Designated Survivor]
# 5271                                                                                                                              [Hanna, Queen of the South, Demon Slayer, Atypical, Family Guy, Preacher, Deception, Game of thrones, 12 Monkeys, Shooter, Lost in Space, Archer, Stranger Things, Outer Banks, Mare of Easttown, The Mentalist, How to get away with murder, Spartacus, Peaky Blinders]
# 5288                                                                                                                                               [Hanna, Daredevil, The Stranger, Cobra Kai, Mr. Robot, Succession, Ozark, Berlin Station, Breaking Bad, Madmen, The Queen's Gambit, Deception, Supergirl, Two and a half men, Game of thrones, Narcos, Outer Banks, The Night Manager, Bojack Horseman]
# 5439                                                                                                                            [Hanna, Daredevil, Queen of the South, Cobra Kai, Demon Slayer, Rick And Morty, Ozark, The Flash, Deception, The Walking Dead, Only Murders in the building, Punisher, Nine Perfect Strangers, The Mentalist, Dark, Designated Survivor, Ragnarok, Perception, The Office]
# 5585                                                                                                                                            [Hanna, One Piece, Queen of the South, Lost, Ozark, Berlin Station, Jack Ryan, Atypical, Family Guy, Preacher, Deception, Dr. House, Two and a half men, Vikings, Sopranos, Sons of Anarchy, 24, Black Clover, Dark, The Alienist, Grimm, Big Little Lies]
# 5799                                     [Daredevil, Elementary, The Blacklist, Demon Slayer, Ozark, Berlin Station, Jack Ryan, Constantine, Travellers, Atypical, Family Guy, Grey's Anatomy, Deception, Two and a half men, The Wire, Kingdom, The Walking Dead, House of Cards, The Big Bang Theory, Teen Wolf, The Mentalist, How to get away with murder, Spartacus, Haven, Shadow and Bone, Lucifer]
# 5966    [Hanna, Daredevil, Inhumans, Arrow, The Stranger, Queen of the South, Cobra Kai, The Blacklist, Mr. Robot, Ozark, Berlin Station, Jack Ryan, Atypical, Family Guy, Emily in Paris, Grey's Anatomy, The Flash, Preacher, True Detective, Dr. House, Two and a half men, Sense 8, Game of thrones, House of Cards, 12 Monkeys, Inside Job, Vikings, The Big Bang Theory, You, Big Little Lies, Dark]
# 6190                                                                                                              [Cobra Kai, The Blacklist, Demon Slayer, The Boys, Succession, Ozark, Alice in Borderland, Preacher, True Detective, The Outsider, Upload, 12 Monkeys, Sopranos, The Big Bang Theory, Lost in Space, Archer, Banshee, Shadow and Bone, Ragnarok, Goliath, Big Little Lies, The IT Crowd]
# 6494                                                                                                      [Daredevil, Queen of the South, Rick And Morty, Mr. Robot, Ozark, Berlin Station, Alice in Borderland, Two and a half men, The Wire, Kingdom, The Walking Dead, The Nevers, Outer Banks, The Mentalist, Homeland, Shadow and Bone, Hunters, The Wheel of Time, Chernobyl, How I met your mother]
# 6760                                                                                                                           [Daredevil, One Piece, Lost, The Blacklist, Demon Slayer, Atypical, Alice in Borderland, Deception, The Wire, Nine Perfect Strangers, Archer, Stranger Things, The Mentalist, Banshee, Designated Survivor, Brooklyn Nine Nine, Outlander, Big Little Lies, Peaky Blinders]
# 6924                                                                                                               [Hanna, Arrow, The Wire, Demon Slayer, Rick And Morty, White Collar, Grey's Anatomy, Alice in Borderland, Preacher, Deception, Supergirl, The Wire, Kingdom, Vikings, Orphan Black, Mindhunter, Black Clover, The Umbrella Academy, The Mentalist, Brooklyn Nine Nine, The White Lotus]
# 7136                                                                                                                               [Daredevil, Elementary, Lost, Cobra Kai, The Blacklist, Demon Slayer, Ozark, Berlin Station, White Collar, Dr Stone, The Walking Dead, Sense 8, House of Cards, Death Note, Punisher, Shooter, The Witcher, The Alienist, Shadow and Bone, Peaky Blinders, The Expanse]
# 7199                                                                                                      [Elementary, The Stranger, One Piece, Queen of the South, Lost, Rick And Morty, Berlin Station, Dr. House, Two and a half men, Kingdom, The Walking Dead, Game of thrones, Fringe, Outer Banks, How to get away with murder, Shadow and Bone, Designated Survivor, Big Little Lies, The Expanse]
# 7206                            [Daredevil, One Piece, Cobra Kai, The Blacklist, Demon Slayer, Mr. Robot, Berlin Station, Jack Ryan, Atypical, Heros, Alice in Borderland, The Flash, Deception, Supergirl, The man in the high castle, Kingdom, 12 Monkeys, Punisher, The Witcher, The Umbrella Academy, Outer Banks, The Mentalist, Loki, Shadow and Bone, Goliath, Big Little Lies, Chernobyl, Startup]
# 7228                                                                                                                                              [The Stranger, Cobra Kai, Mr. Robot, Ozark, Atypical, The Flash, Breaking Bad, True Detective, Deception, The Walking Dead, Sense 8, Locke & Key, 12 Monkeys, Vikings, Lost in Space, Stranger Things, The Mentalist, The Night Manager, You, Chernobyl]
# 7254                                                                                                                                  [Hanna, The Stranger, One Piece, The Blacklist, Mr. Robot, Ozark, Atypical, White Collar, True Detective, Kingdom, The Walking Dead, Game of thrones, Sopranos, Archer, Space Force, The Mentalist, How to get away with murder, Banshee, Shadow and Bone, Ragnarok]
# 7263                                                                    [Arrow, Queen of the South, Cobra Kai, The Blacklist, Mr. Robot, Ozark, Travellers, Dr. House, Two and a half men, The Walking Dead, Sopranos, Lost in Space, Outer Banks, Banshee, Shadow and Bone, Designated Survivor, Brooklyn Nine Nine, Outlander, The Night Manager, Chernobyl, The Handmaid's Tale, How I met your mother]
# 8037            [Queen of the South, Lost, The Blacklist, Mr. Robot, Succession, Ozark, Berlin Station, Atypical, Family Guy, Alice in Borderland, True Detective, Deception, The man in the high castle, Two and a half men, The Wire, Locke & Key, Only Murders in the building, Inside Job, Inside Job, Black Clover, Archer, Dexter, Dark, The Newsroom, Banshee, Shadow and Bone, Chernobyl, Startup]
# 8491                                                                                                                       [Daredevil, Cobra Kai, The Blacklist, Demon Slayer, Ozark, Berlin Station, Breaking Bad, Madmen, The Walking Dead, Black Clover, Stranger Things, Locke & Key, How to get away with murder, Banshee, Shadow and Bone, Goliath, South Park, Big Little Lies, Chernobyl, Startup]
# 8702                                                                                                                          [Cobra Kai, The Boys, Succession, Ozark, Family Guy, Preacher, True Detective, Deception, The Outsider, Sopranos, The Vampire Diaries, Peaky Blinders, Archer, Space Force, Banshee, Spartacus, Shadow and Bone, The Night Manager, Hunters, Schitts Creek, Big Little Lies]
# 9257                                                                                                                     [One Piece, Queen of the South, The Blacklist, Mr. Robot, Ozark, Atypical, Family Guy, Breaking Bad, Deception, Upload, Two and a half men, Lupin, Mirzapur, 12 Monkeys, Vikings, Fringe, Black Clover, Stranger Things, Dark, Squid Game, Spartacus, Outlander, Big Little Lies]

# %% [markdown]
# ### Encoding :

# %%
shows_encoded = shows['Watched'].str.join(',').str.get_dummies(',')

# %%
shows_encoded
# Out:
#       12 Monkeys  24  Absentia  Alice in Borderland  American Gods  Archer  \
# 85             1   0         1                    0              0       0
# 361            0   0         0                    0              0       0
# 601            0   0         1                    0              0       0
# 733            0   0         0                    0              0       0
# 959            1   0         0                    0              0       0
# 1189           0   0         0                    0              0       1
# 1229           1   0         0                    1              1       0
# 1255           1   0         0                    0              0       1
# 1382           0   0         0                    0              0       0
# 1812           0   0         0                    1              0       0
# 1906           1   0         0                    0              0       0
# 2931           0   0         0                    0              0       0
# 3183           0   0         0                    1              0       0
# 3376           1   0         0                    0              0       0
# 3479           1   0         0                    1              0       1
# 4029           0   0         0                    0              0       0
# 4040           1   0         0                    0              0       0
# 4211           0   0         0                    1              0       0
# 4711           0   0         0                    1              0       0
# 4795           0   0         0                    1              0       0
# 4912           0   0         0                    0              0       0
# 4945           1   0         0                    0              0       1
# 5271           1   0         0                    0              0       1
# 5288           0   0         0                    0              0       0
# 5439           0   0         0                    0              0       0
# 5585           0   1         0                    0              0       0
# 5799           0   0         0                    0              0       0
# 5966           1   0         0                    0              0       0
# 6190           1   0         0                    1              0       1
# 6494           0   0         0                    1              0       0
# 6760           0   0         0                    1              0       1
# 6924           0   0         0                    1              0       0
# 7136           0   0         0                    0              0       0
# 7199           0   0         0                    0              0       0
# 7206           1   0         0                    1              0       0
# 7228           1   0         0                    0              0       0
# 7254           0   0         0                    0              0       1
# 7263           0   0         0                    0              0       0
# 8037           0   0         0                    1              0       1
# 8491           0   0         0                    0              0       0
# 8702           0   0         0                    0              0       1
# 9257           1   0         0                    0              0       0
#
#       Arrow  Atypical  Banshee  Berlin Station  ...  \
# 85        0         0        0               1  ...
# 361       0         0        0               0  ...
# 601       0         1        0               1  ...
# 733       0         0        1               0  ...
# 959       0         1        0               0  ...
# 1189      1         1        1               0  ...
# 1229      0         1        1               1  ...
# 1255      0         1        0               0  ...
# 1382      0         0        0               1  ...
# 1812      0         1        0               0  ...
# 1906      0         0        0               0  ...
# 2931      0         0        0               0  ...
# 3183      0         0        0               0  ...
# 3376      0         1        0               0  ...
# 3479      0         1        1               1  ...
# 4029      0         1        1               1  ...
# 4040      0         1        0               1  ...
# 4211      1         1        0               0  ...
# 4711      1         1        0               1  ...
# 4795      1         1        0               0  ...
# 4912      0         0        0               0  ...
# 4945      0         1        0               1  ...
# 5271      0         1        0               0  ...
# 5288      0         0        0               1  ...
# 5439      0         0        0               0  ...
# 5585      0         1        0               1  ...
# 5799      0         1        0               1  ...
# 5966      1         1        0               1  ...
# 6190      0         0        1               0  ...
# 6494      0         0        0               1  ...
# 6760      0         1        1               0  ...
# 6924      1         0        0               0  ...
# 7136      0         0        0               1  ...
# 7199      0         0        0               1  ...
# 7206      0         1        0               1  ...
# 7228      0         1        0               0  ...
# 7254      0         1        1               0  ...
# 7263      1         0        1               0  ...
# 8037      0         1        1               1  ...
# 8491      0         0        1               1  ...
# 8702      0         0        1               0  ...
# 9257      0         1        0               0  ...
#
#       The man in the high castle  Travellers  True Detective  \
# 85                             0           0               0
# 361                            1           0               0
# 601                            0           0               0
# 733                            0           0               0
# 959                            0           0               0
# 1189                           0           1               1
# 1229                           0           0               0
# 1255                           0           0               0
# 1382                           0           0               0
# 1812                           0           1               0
# 1906                           0           0               0
# 2931                           1           0               0
# 3183                           0           0               0
# 3376                           0           0               0
# 3479                           1           0               0
# 4029                           0           0               0
# 4040                           0           0               0
# 4211                           0           0               0
# 4711                           0           0               0
# 4795                           0           0               0
# 4912                           1           0               0
# 4945                           0           1               0
# 5271                           0           0               0
# 5288                           0           0               0
# 5439                           0           0               0
# 5585                           0           0               0
# 5799                           0           1               0
# 5966                           0           0               1
# 6190                           0           0               1
# 6494                           0           0               0
# 6760                           0           0               0
# 6924                           0           0               0
# 7136                           0           0               0
# 7199                           0           0               0
# 7206                           1           0               0
# 7228                           0           0               1
# 7254                           0           0               1
# 7263                           0           1               0
# 8037                           1           0               1
# 8491                           0           0               0
# 8702                           0           0               1
# 9257                           0           0               0
#
#       Two and a half men  Upload  Vikings  Westworld  White Collar  X-Files  \
# 85                     1       0        0          0             0        0
# 361                    0       0        0          0             0        0
# 601                    0       0        0          0             0        0
# 733                    0       0        0          0             0        0
# 959                    0       0        0          0             0        0
# 1189                   0       0        1          0             0        0
# 1229                   0       1        0          0             0        0
# 1255                   1       0        0          0             0        0
# 1382                   0       0        0          0             0        1
# 1812                   0       0        0          1             0        0
# 1906                   0       0        1          0             0        0
# 2931                   0       0        0          0             0        0
# 3183                   1       0        1          0             0        0
# 3376                   0       0        0          0             0        1
# 3479                   1       0        0          0             0        0
# 4029                   0       0        0          0             0        0
# 4040                   0       0        0          0             1        0
# 4211                   0       0        0          0             0        0
# 4711                   0       0        1          0             0        0
# 4795                   0       0        0          0             0        0
# 4912                   1       0        0          0             0        0
# 4945                   0       0        0          0             1        0
# 5271                   0       0        0          0             0        0
# 5288                   1       0        0          0             0        0
# 5439                   0       0        0          0             0        0
# 5585                   1       0        1          0             0        0
# 5799                   1       0        0          0             0        0
# 5966                   1       0        1          0             0        0
# 6190                   0       1        0          0             0        0
# 6494                   1       0        0          0             0        0
# 6760                   0       0        0          0             0        0
# 6924                   0       0        1          0             1        0
# 7136                   0       0        0          0             1        0
# 7199                   1       0        0          0             0        0
# 7206                   0       0        0          0             0        0
# 7228                   0       0        1          0             0        0
# 7254                   0       0        0          0             1        0
# 7263                   1       0        0          0             0        0
# 8037                   1       0        0          0             0        0
# 8491                   0       0        0          0             0        0
# 8702                   0       0        0          0             0        0
# 9257                   1       1        1          0             0        0
#
#       You
# 85      1
# 361     0
# 601     0
# 733     0
# 959     0
# 1189    0
# 1229    0
# 1255    0
# 1382    0
# 1812    0
# 1906    0
# 2931    0
# 3183    0
# 3376    0
# 3479    0
# 4029    0
# 4040    0
# 4211    0
# 4711    0
# 4795    0
# 4912    0
# 4945    0
# 5271    0
# 5288    0
# 5439    0
# 5585    0
# 5799    0
# 5966    1
# 6190    0
# 6494    0
# 6760    0
# 6924    0
# 7136    0
# 7199    0
# 7206    0
# 7228    1
# 7254    0
# 7263    0
# 8037    0
# 8491    0
# 8702    0
# 9257    0
#
# [42 rows x 131 columns]

# %%
shows_encoded.columns.tolist()
# Out:
# ['12 Monkeys',
#  '24',
#  'Absentia',
#  'Alice in Borderland',
#  'American Gods',
#  'Archer',
#  'Arrow',
#  'Atypical',
#  'Banshee',
#  'Berlin Station',
#  'Better Call Saul',
#  'Big Little Lies',
#  'Black Clover',
#  'Bojack Horseman',
#  'Breaking Bad',
#  'Brooklyn Nine Nine',
#  'Chernobyl',
#  'Cobra Kai',
#  'Constantine',
#  'Daredevil',
#  'Dark',
#  'Death Note',
#  'Deception',
#  'Demon Slayer',
#  'Designated Survivor',
#  'Dexter',
#  'Doctor Who',
#  'Dr Stone',
#  'Dr. House',
#  'Elementary',
#  'Emily in Paris',
#  'Family Guy',
#  'Friends',
#  'Fringe',
#  'Game of thrones',
#  'Goliath',
#  "Grey's Anatomy",
#  'Grimm',
#  'Hanna',
#  'Haven',
#  'Heros',
#  'Homeland',
#  'House of Cards',
#  'How I met your mother',
#  'How to get away with murder',
#  'Hunters',
#  'Inhumans',
#  'Inside Job',
#  'Into the night',
#  'Jack Ryan',
#  'Kingdom',
#  'Locke & Key',
#  'Loki',
#  'Lost',
#  'Lost in Space',
#  'Lucifer',
#  'Lupin',
#  'Madmen',
#  'Mare of Easttown',
#  'Mindhunter',
#  'Mirzapur',
#  'Mr. Robot',
#  'Narcos',
#  'Nine Perfect Strangers',
#  'One Piece',
#  'Only Murders in the building',
#  'Orphan Black',
#  'Outer Banks',
#  'Outlander',
#  'Ozark',
#  'Peaky Blinders',
#  'Perception',
#  'Person of Interest',
#  'Preacher',
#  'Punisher',
#  'Queen of the South',
#  'Ragnarok',
#  'Rick And Morty',
#  'Rome',
#  'Sacred Games',
#  'Schitts Creek',
#  'Sense 8',
#  'Shadow and Bone',
#  'Sherlock',
#  'Shooter',
#  'Sons of Anarchy',
#  'Sopranos',
#  'South Park',
#  'Space Force',
#  'Spartacus',
#  'Squid Game',
#  'Startup',
#  'Stranger Things',
#  'Succession',
#  'Supergirl',
#  'Teen Wolf',
#  'The Alienist',
#  'The Big Bang Theory',
#  'The Blacklist',
#  'The Boys',
#  'The Expanse',
#  'The Flash',
#  'The Good Doctor',
#  "The Handmaid's Tale",
#  'The IT Crowd',
#  'The Innocent',
#  'The Mentalist',
#  'The Nevers',
#  'The Newsroom',
#  'The Night Manager',
#  'The Office',
#  'The Outsider',
#  "The Queen's Gambit",
#  'The Stranger',
#  'The Umbrella Academy',
#  'The Vampire Diaries',
#  'The Walking Dead',
#  'The Wheel of Time',
#  'The White Lotus',
#  'The Wire',
#  'The Witcher',
#  'The man in the high castle',
#  'Travellers',
#  'True Detective',
#  'Two and a half men',
#  'Upload',
#  'Vikings',
#  'Westworld',
#  'White Collar',
#  'X-Files',
#  'You']

# %% [markdown]
# ## Training Phase :

# %% [markdown]
# ### Selecting the most frequently apprearing item sets using the Apriori algorithm :

# %%
frequent_itemsets = (apriori(shows_encoded,min_support=0.2, use_colnames=True)).sort_values(by='support', ascending=False)
frequent_itemsets
# Out:
# /Users/mac/Library/Python/3.9/lib/python/site-packages/mlxtend/frequent_patterns/fpcommon.py:109: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#       support                           itemsets
# 26   0.738095                            (Ozark)
# 34   0.642857                    (The Blacklist)
# 3    0.571429                         (Atypical)
# 22   0.500000                        (Mr. Robot)
# 119  0.500000             (The Blacklist, Ozark)
# ..        ...                                ...
# 44   0.214286      (12 Monkeys, Stranger Things)
# 40   0.214286                          (Vikings)
# 76   0.214286                 (Chernobyl, Ozark)
# 133  0.214286  (The Mentalist, The Walking Dead)
# 88   0.214286             (Mr. Robot, Deception)
#
# [177 rows x 2 columns]

# %% [markdown]
# ### Applying the association rules modele :

# %%
rules = association_rules(frequent_itemsets, metric='lift')
rules
# Out:
#             antecedents         consequents  antecedent support  \
# 0       (The Blacklist)             (Ozark)            0.642857
# 1               (Ozark)     (The Blacklist)            0.738095
# 2            (Atypical)             (Ozark)            0.571429
# 3               (Ozark)          (Atypical)            0.738095
# 4           (Mr. Robot)             (Ozark)            0.500000
# ..                  ...                 ...                 ...
# 459             (Ozark)         (Chernobyl)            0.738095
# 460     (The Mentalist)  (The Walking Dead)            0.428571
# 461  (The Walking Dead)     (The Mentalist)            0.476190
# 462         (Mr. Robot)         (Deception)            0.500000
# 463         (Deception)         (Mr. Robot)            0.476190
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 0              0.738095  0.500000    0.777778  1.053763  0.025510    1.178571
# 1              0.642857  0.500000    0.677419  1.053763  0.025510    1.107143
# 2              0.738095  0.452381    0.791667  1.072581  0.030612    1.257143
# 3              0.571429  0.452381    0.612903  1.072581  0.030612    1.107143
# 4              0.738095  0.428571    0.857143  1.161290  0.059524    1.833333
# ..                  ...       ...         ...       ...       ...         ...
# 459            0.285714  0.214286    0.290323  1.016129  0.003401    1.006494
# 460            0.476190  0.214286    0.500000  1.050000  0.010204    1.047619
# 461            0.428571  0.214286    0.450000  1.050000  0.010204    1.038961
# 462            0.476190  0.214286    0.428571  0.900000 -0.023810    0.916667
# 463            0.500000  0.214286    0.450000  0.900000 -0.023810    0.909091
#
#      zhangs_metric
# 0         0.142857
# 1         0.194805
# 2         0.157895
# 3         0.258373
# 4         0.277778
# ..             ...
# 459       0.060606
# 460       0.083333
# 461       0.090909
# 462      -0.181818
# 463      -0.175000
#
# [464 rows x 10 columns]

# %%
# Sort the rules by support in descending order
rules_df = rules.sort_values(by='lift', ascending=False)
rules_df
# Out:
#                                    antecedents  \
# 295                (The Blacklist, Family Guy)
# 298                 (Atypical, Berlin Station)
# 302                               (Family Guy)
# 291  (The Blacklist, Atypical, Berlin Station)
# 315                               (Family Guy)
# ..                                         ...
# 155                                    (Hanna)
# 448                              (Outer Banks)
# 72                              (Demon Slayer)
# 449                                    (Ozark)
# 73                                     (Ozark)
#
#                                    consequents  antecedent support  \
# 295                 (Atypical, Berlin Station)            0.333333
# 298                (The Blacklist, Family Guy)            0.285714
# 302  (The Blacklist, Atypical, Berlin Station)            0.452381
# 291                               (Family Guy)            0.238095
# 315          (Atypical, Ozark, Berlin Station)            0.452381
# ..                                         ...                 ...
# 155                                    (Ozark)            0.380952
# 448                                    (Ozark)            0.357143
# 72                                     (Ozark)            0.476190
# 449                              (Outer Banks)            0.738095
# 73                              (Demon Slayer)            0.738095
#
#      consequent support   support  confidence      lift  leverage  conviction  \
# 295            0.285714  0.214286    0.642857  2.250000  0.119048    2.000000
# 298            0.333333  0.214286    0.750000  2.250000  0.119048    2.666667
# 302            0.238095  0.214286    0.473684  1.989474  0.106576    1.447619
# 291            0.452381  0.214286    0.900000  1.989474  0.106576    5.476190
# 315            0.238095  0.214286    0.473684  1.989474  0.106576    1.447619
# ..                  ...       ...         ...       ...       ...         ...
# 155            0.738095  0.238095    0.625000  0.846774 -0.043084    0.698413
# 448            0.738095  0.214286    0.600000  0.812903 -0.049320    0.654762
# 72             0.738095  0.285714    0.600000  0.812903 -0.065760    0.654762
# 449            0.357143  0.214286    0.290323  0.812903 -0.049320    0.905844
# 73             0.476190  0.285714    0.387097  0.812903 -0.065760    0.854637
#
#      zhangs_metric
# 295       0.833333
# 298       0.777778
# 302       0.908213
# 291       0.652778
# 315       0.908213
# ..             ...
# 155      -0.226190
# 448      -0.263636
# 72       -0.305263
# 449      -0.467742
# 73       -0.467742
#
# [464 rows x 10 columns]

# %%
rules_df = rules.sort_values(by='support', ascending=False)
rules_df
rules_df.to_csv("./Apriori_rules.csv")

# %%
def extract_book_names(frozenset_value):
    return list(frozenset_value)

# Apply the function to the 'antecedents' column
rules_df['book_names'] = rules_df['antecedents'].apply(extract_book_names)
rules_df['recomendation'] = rules_df['consequents'].apply(extract_book_names)
# Display the DataFrame
print(rules_df)
rules_df.to_csv("./Apriorii_rules.csv")
# Out:
#                        antecedents                    consequents  \
# 0                  (The Blacklist)                        (Ozark)
# 1                          (Ozark)                (The Blacklist)
# 2                       (Atypical)                        (Ozark)
# 3                          (Ozark)                     (Atypical)
# 4                      (Mr. Robot)                        (Ozark)
# ..                             ...                            ...
# 335              (Shadow and Bone)  (The Blacklist, Demon Slayer)
# 337  (The Blacklist, Demon Slayer)                        (Ozark)
# 338          (Demon Slayer, Ozark)                (The Blacklist)
# 339                (The Blacklist)          (Demon Slayer, Ozark)
# 463                    (Deception)                    (Mr. Robot)
#
#      antecedent support  consequent support   support  confidence      lift  \
# 0              0.642857            0.738095  0.500000    0.777778  1.053763
# 1              0.738095            0.642857  0.500000    0.677419  1.053763
# 2              0.571429            0.738095  0.452381    0.791667  1.072581
# 3              0.738095            0.571429  0.452381    0.612903  1.072581
# 4              0.500000            0.738095  0.428571    0.857143  1.161290
# ..                  ...                 ...       ...         ...       ...
# 335            0.476190            0.333333  0.214286    0.450000  1.350000
# 337            0.333333            0.738095  0.214286    0.642857  0.870968
# 338            0.285714            0.642857  0.214286    0.750000  1.166667
# 339            0.642857            0.285714  0.214286    0.333333  1.166667
# 463            0.476190            0.500000  0.214286    0.450000  0.900000
#
#      leverage  conviction  zhangs_metric                     book_names  \
# 0    0.025510    1.178571       0.142857                [The Blacklist]
# 1    0.025510    1.107143       0.194805                        [Ozark]
# 2    0.030612    1.257143       0.157895                     [Atypical]
# 3    0.030612    1.107143       0.258373                        [Ozark]
# 4    0.059524    1.833333       0.277778                    [Mr. Robot]
# ..        ...         ...            ...                            ...
# 335  0.055556    1.212121       0.494949              [Shadow and Bone]
# 337 -0.031746    0.733333      -0.181818  [The Blacklist, Demon Slayer]
# 338  0.030612    1.428571       0.200000          [Demon Slayer, Ozark]
# 339  0.030612    1.071429       0.400000                [The Blacklist]
# 463 -0.023810    0.909091      -0.175000                    [Deception]
#
#                      recomendation
# 0                          [Ozark]
# 1                  [The Blacklist]
# 2                          [Ozark]
# 3                       [Atypical]
# 4                          [Ozark]
# ..                             ...
# 335  [The Blacklist, Demon Slayer]
# 337                        [Ozark]
# 338                [The Blacklist]
# 339          [Demon Slayer, Ozark]
# 463                    [Mr. Robot]
#
# [464 rows x 12 columns]

# %% [markdown]
# def associatonRulesFunction(data=shows_encoded?

# %% [markdown]
# ### Functions :

# %%
def cleanList(l):
    ## Deleting the useless String parts 
    for i in range(len(l)) :
        l[i]=str(l[i]).replace("frozenset({'",'')
        l[i]=l[i].replace("'})",'')
        l[i]=str(l[i]).replace('frozenset({"','')
        l[i]=l[i].replace('"})','')
        l[i]=l[i].replace('", "',',')
        l[i]=l[i].replace("', '",',')
        l[i]=l[i].replace("', ",',')
        l[i]=l[i].replace(", '",',')
        l[i]=l[i].replace('"','')
    return l;


def Recommended(show,number=4):
    ## A function that will only select the first 4 Series that has the highest support with the desired show 
    desired_antecedents_value = {show}
    desired_rows = rules_df.loc[rules_df['antecedents'] == desired_antecedents_value]

    ## We only choose the lines in the rules table that has only one elemnt 
    filtered_rows = desired_rows[desired_rows['consequents'].apply(lambda x: len(x) == 1)] 
    
    if not filtered_rows.empty:
        first_4_rows = filtered_rows.head(number)
        result_list = first_4_rows['consequents'].tolist()
        
        return cleanList(result_list)

# %% [markdown]
# ### Converting the frequent itemsets into a dataframe and exporting it into a csv

# %%
dataset=frequent_itemsets['itemsets'].tolist()
dataset = cleanList(dataset)
dataset
# Out:
# ['Ozark',
#  'The Blacklist',
#  'Atypical',
#  'Mr. Robot',
#  'The Blacklist,Ozark',
#  'The Walking Dead',
#  'Deception',
#  'Shadow and Bone',
#  'Demon Slayer',
#  'Atypical,Ozark',
#  'Family Guy',
#  'Berlin Station',
#  'Mr. Robot,Ozark',
#  'The Blacklist,Atypical',
#  'The Mentalist',
#  'Daredevil',
#  'Ozark,Family Guy',
#  'Atypical,Family Guy',
#  'Ozark,The Walking Dead',
#  'Hanna',
#  'Stranger Things',
#  'The Wire',
#  'Ozark,Deception',
#  'Ozark,Berlin Station',
#  'Queen of the South',
#  '12 Monkeys',
#  'Outer Banks',
#  'The Blacklist,Atypical,Ozark',
#  'The Blacklist,Demon Slayer',
#  'Cobra Kai',
#  'The Blacklist,Family Guy',
#  'Mr. Robot,The Blacklist',
#  'Ozark,Shadow and Bone',
#  'Two and a half men',
#  'Atypical,Deception',
#  'The Blacklist,Shadow and Bone',
#  'The Stranger',
#  'Big Little Lies',
#  'Dr. House',
#  'Mr. Robot,Atypical',
#  'Alice in Borderland',
#  'The Blacklist,Atypical,Family Guy',
#  'Ozark,The Mentalist',
#  'The Blacklist,The Walking Dead',
#  'Atypical,Family Guy,Ozark',
#  'Atypical,The Mentalist',
#  'Chernobyl',
#  'Atypical,Stranger Things',
#  'The Blacklist,Ozark,Family Guy',
#  'Deception,The Mentalist',
#  'The Blacklist,Deception',
#  'Banshee',
#  'Family Guy,Deception',
#  'Daredevil,Demon Slayer',
#  'Demon Slayer,Ozark',
#  'Dark',
#  'Mr. Robot,The Blacklist,Ozark',
#  'The Blacklist,12 Monkeys',
#  'The Blacklist,Berlin Station',
#  'Jack Ryan',
#  'Atypical,12 Monkeys',
#  'Ozark,Cobra Kai',
#  'Atypical,Berlin Station',
#  'The Wire,The Mentalist',
#  'Mr. Robot,Family Guy',
#  'The Blacklist,Ozark,Shadow and Bone',
#  'Ozark,Stranger Things',
#  'Queen of the South,Ozark',
#  'Ozark,The Wire',
#  'Mr. Robot,Atypical,Ozark',
#  'Ozark,Two and a half men',
#  'Daredevil,Ozark',
#  'The Blacklist,Ozark,The Walking Dead',
#  'The Blacklist,Stranger Things',
#  'The Blacklist,Atypical,Family Guy,Ozark',
#  'Succession',
#  'Mr. Robot,Berlin Station',
#  'Family Guy,Berlin Station',
#  'Preacher',
#  'Demon Slayer,Atypical',
#  'Spartacus',
#  'Daredevil,Berlin Station',
#  'The Blacklist,Atypical,Deception',
#  'Atypical,Jack Ryan',
#  'Ozark,Hanna',
#  'The Blacklist,Ozark,Berlin Station',
#  'Jack Ryan,Ozark',
#  'The Blacklist,The Mentalist',
#  'Ozark,Family Guy,Berlin Station',
#  'The Walking Dead,Shadow and Bone',
#  'Atypical,Ozark,The Walking Dead',
#  'Atypical,The Walking Dead',
#  'Atypical,Ozark,The Mentalist',
#  'Outer Banks,Shadow and Bone',
#  'The Blacklist,Alice in Borderland',
#  'The Blacklist,Queen of the South',
#  'Mr. Robot,The Blacklist,Atypical',
#  'Lupin',
#  'Ozark,The Stranger',
#  '12 Monkeys,Ozark',
#  'Sopranos',
#  'The Blacklist,The Wire',
#  'Ozark,Family Guy,Deception',
#  'Atypical,Family Guy,Berlin Station',
#  'Atypical,Ozark,Deception',
#  'Berlin Station,Shadow and Bone',
#  'Atypical,Family Guy,Deception',
#  'The Blacklist,Atypical,Berlin Station',
#  'The Blacklist,Daredevil',
#  'Archer',
#  'Game of thrones',
#  'Berlin Station,Dr. House',
#  'Atypical,Ozark,Berlin Station',
#  'The Blacklist,Atypical,12 Monkeys',
#  'Banshee,The Blacklist',
#  'Mr. Robot,Ozark,Family Guy',
#  'Demon Slayer,Shadow and Bone',
#  'Atypical,The Wire',
#  'Ozark,Dr. House',
#  '12 Monkeys,Family Guy',
#  'Atypical,Jack Ryan,Ozark',
#  'One Piece',
#  'Mr. Robot,Atypical,Family Guy',
#  'Only Murders in the building',
#  'Berlin Station,Two and a half men',
#  'Atypical,Ozark,Stranger Things',
#  'Lost in Space',
#  'The Blacklist,Atypical,Family Guy,Berlin Station',
#  'Atypical,Family Guy,Ozark,Berlin Station',
#  'The Wire,Ozark,The Mentalist',
#  "Grey's Anatomy",
#  'Lost',
#  'Mr. Robot,The Blacklist,Family Guy',
#  'The Blacklist,Demon Slayer,Shadow and Bone',
#  'The Blacklist,Ozark,Demon Slayer',
#  'The Blacklist,Ozark,Deception',
#  'The Blacklist,Family Guy,Deception',
#  'The Blacklist,Demon Slayer,Daredevil',
#  'The Blacklist,Family Guy,Berlin Station',
#  'The Blacklist,Atypical,Demon Slayer',
#  'The Blacklist,Atypical,Stranger Things',
#  'Atypical,The Wire,Ozark',
#  'The Blacklist,Atypical,The Mentalist',
#  'Queen of the South,Two and a half men',
#  'Atypical,Deception,The Mentalist',
#  'Atypical,Spartacus',
#  'The Blacklist,Chernobyl',
#  'The Blacklist,Cobra Kai',
#  'Daredevil,Shadow and Bone',
#  'Dark,Ozark',
#  'Demon Slayer,Deception',
#  'Hanna,Deception',
#  'Demon Slayer,Berlin Station',
#  'Big Little Lies,Berlin Station',
#  'The Wire,Deception',
#  'Mr. Robot,Demon Slayer',
#  'Banshee,Ozark',
#  'Demon Slayer,The Mentalist',
#  'The Blacklist,Dr. House',
#  'Family Guy,Hanna',
#  'The Blacklist,Hanna',
#  'Atypical,12 Monkeys,Family Guy',
#  'The Blacklist,Jack Ryan',
#  'Atypical,Hanna',
#  'Mr. Robot,Shadow and Bone',
#  'Atypical,Dr. House',
#  'Mr. Robot,The Mentalist',
#  'Mr. Robot,Two and a half men',
#  'Outer Banks,Ozark',
#  'Ozark,Alice in Borderland',
#  'Succession,Ozark',
#  'Atypical,Alice in Borderland',
#  '12 Monkeys,Stranger Things',
#  'Vikings',
#  'Chernobyl,Ozark',
#  'The Mentalist,The Walking Dead',
#  'Mr. Robot,Deception']

# %%
result = (pd.DataFrame({"itemsets": dataset,
                       "support": frequent_itemsets['support']})).reset_index(drop=True)
result.to_csv('./Apriori.csv')
result
# Out:
#                            itemsets   support
# 0                             Ozark  0.738095
# 1                     The Blacklist  0.642857
# 2                          Atypical  0.571429
# 3                         Mr. Robot  0.500000
# 4               The Blacklist,Ozark  0.500000
# ..                              ...       ...
# 172      12 Monkeys,Stranger Things  0.214286
# 173                         Vikings  0.214286
# 174                 Chernobyl,Ozark  0.214286
# 175  The Mentalist,The Walking Dead  0.214286
# 176             Mr. Robot,Deception  0.214286
#
# [177 rows x 2 columns]
